# %%
from new_plot import *
set_things()
# Out:
# /opt/anaconda3/envs/gideon/lib/python3.8/_collections_abc.py:832: MatplotlibDeprecationWarning:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /opt/anaconda3/envs/gideon/lib/python3.8/_collections_abc.py:832: MatplotlibDeprecationWarning:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /opt/anaconda3/envs/gideon/lib/python3.8/_collections_abc.py:832: MatplotlibDeprecationWarning:
# The animation.html_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /opt/anaconda3/envs/gideon/lib/python3.8/_collections_abc.py:832: MatplotlibDeprecationWarning:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# ...

# %%
set_font(weight='normal', size=30)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]
# LLaMa, LLaMat, LLaMat-Chat, and LLaMA-Chat-F
micro_f1_3 = [92.394, 89.611, 84.715, 88.81]
macro_f1_3 = [87.414, 83.883, 78.406, 82.742]

# X-axis labels
scores = ["Micro-F1", "Macro-F1"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axi

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_3 = [92.207, 91.614, 91.162, 91.33] 
macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

# X-axis labels
scores = ["Micro-F1", "Macro-F1"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(8, 8))

# Plot bars for each category
# ax.bar(positions[0], [micro_f1_3[0], macro_f1_3[0]], bar_width, label="Chat", color="#D55E00") 
# ax.bar(positions[1], [micro_f1_3[1], macro_f1_3[1]], bar_width, label="Base", color="#0072B2") #1E88E5
# ax.bar(positions[2], [micro_f1_3[2], macro_f1_3[2]], bar_width, label="Chat (finetuned)", color="#F0E442")
# ax.bar(positions[3], [micro_f1_3[3], macro_f1_3[3]], bar_width, label="Base (finetuned)", color="#CC79A7")

ax.bar(positions[0], [micro_f1_3[0], macro_f1_3[0]], bar_width, label="Chat", color="#00796B") 
ax.bar(positions[1], [micro_f1_3[1], macro_f1_3[1]], bar_width, label="Base", color="#E91E63") #1E88E5
ax.bar(positions[2], [micro_f1_3[2], macro_f1_3[2]], bar_width, label="Chat (finetuned)", color="#FFCA28")
ax.bar(positions[3], [micro_f1_3[3], macro_f1_3[3]], bar_width, label="Base (finetuned)", color="#2196F3")

# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)


plt.show()

# %% [markdown]
# <h2> for legend

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]


micro_f1_3 = [92.394, 89.611, 84.715, 88.81]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [92.207, 91.614, 91.162, 91.33] 


macro_f1_2_std_l3 = [0.659, 0.697, 0.735, 1.189]
micro_f1_2_std_l3 = [0.312, 0.535, 0.378, 0.739]

macro_f1_2_std_l2 = [0.494, 0.735, 0.491,0.778]
micro_f1_2_std_l2 = [0.325,  0.36,  0.26, 0.402]


llama3_chat_noft_Macro_f1 = 29.532
llama3_chat_noft_Micro_f1 = 34.738

llama2_chat_noft_Macro_f1 = 12.88
llama2_chat_noft_Micro_f1 = 15.294

# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

# Lighter pink shades
pinks = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
lighter_pinks = ["#FCE4EC", "#FAD1E7", "#F6A5C9", "#F48FB1", "#F06292", "#EC9BAA", "#E391A0", "#D97896", "#CF607C", "#C54668"]

# Lighter blue shades
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
lighter_blues = ["#E3F2FD", "#BBDEFB", "#90CAF9", "#64B5F6", "#42A5F5", "#1E88E5", "#1565C0", "#2196F3", "#82B1FF", "#B3E5FC"]


news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0], macro_f1_3[0]], bar_width, yerr= [micro_f1_2_std_l3[0], micro_f1_2_std_l2[0]], ec='k', label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1], macro_f1_3[1]], bar_width, yerr= [micro_f1_2_std_l3[1], micro_f1_2_std_l2[1]], ec='k', label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2], macro_f1_3[2]], bar_width, yerr= [micro_f1_2_std_l3[2], micro_f1_2_std_l2[2]], ec='k', label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3], macro_f1_3[3]], bar_width, yerr= [micro_f1_2_std_l3[3], micro_f1_2_std_l2[3]], ec='k', label="LLaMA-FT", color=pinks[-1])

# ax.errorbar(positions[0], [micro_f1_3[0], macro_f1_3[0]], )
# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Micro-F1")
ax.set_xticks(x)
ax.set_xticklabels(scores)
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)
# plt.ylim(60,100)

# ax.set_yticklabels([60,70,80,90,100])
# # Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'a', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside


ax.set_ylim(70,100)
# plt.savefig('fig2_legend_a.png',dpi=600, bbox_inches='tight')
plt.show()

# %%
news
# Out:
# ['#BBDEFB', '#F8BBD0', '#B2DFDB', '#FFE0B2']

# %% [markdown]
# <h2> performance comparison

# %%
micro_f1_3_new = [100*(m-llama3_chat_noft_Micro_f1)/llama3_chat_noft_Micro_f1 for m in micro_f1_3]
macro_f1_3_new = [100*(m-llama2_chat_noft_Micro_f1)/llama2_chat_noft_Micro_f1 for m in macro_f1_3]
micro_f1_3_new
# Out:
# [165.9738614773447, 157.96246185733204, 143.86838620530833, 155.6566296274973]

# %%
llama3_chat_noft_Micro_f1
# Out:
# 34.738

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]


micro_f1_3 = [92.394, 89.611, 84.715, 88.81]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [92.207, 91.614, 91.162, 91.33] 


macro_f1_2_std_l3 = [0.659, 0.697, 0.735, 1.189]
micro_f1_2_std_l3 = [0.312, 0.535, 0.378, 0.739]

macro_f1_2_std_l2 = [0.494, 0.735, 0.491,0.778]
micro_f1_2_std_l2 = [0.325,  0.36,  0.26, 0.402]


llama3_chat_noft_Macro_f1 = 0 #29.532
llama3_chat_noft_Micro_f1 = 0 #34.738

llama2_chat_noft_Macro_f1 = 0 #12.88
llama2_chat_noft_Micro_f1 = 0 #15.294

# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

# Lighter pink shades
pinks = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
lighter_pinks = ["#FCE4EC", "#FAD1E7", "#F6A5C9", "#F48FB1", "#F06292", "#EC9BAA", "#E391A0", "#D97896", "#CF607C", "#C54668"]

# Lighter blue shades
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
lighter_blues = ["#E3F2FD", "#BBDEFB", "#90CAF9", "#64B5F6", "#42A5F5", "#1E88E5", "#1565C0", "#2196F3", "#82B1FF", "#B3E5FC"]


news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0] - llama3_chat_noft_Micro_f1, macro_f1_3[0] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[0], micro_f1_2_std_l2[0]], ec='k', label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1] - llama3_chat_noft_Micro_f1, macro_f1_3[1] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[1], micro_f1_2_std_l2[1]], ec='k', label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2] - llama3_chat_noft_Micro_f1, macro_f1_3[2] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[2], micro_f1_2_std_l2[2]], ec='k', label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3] - llama3_chat_noft_Micro_f1, macro_f1_3[3] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[3], micro_f1_2_std_l2[3]], ec='k', label="LLaMA-FT", color=pinks[-1])

# ax.errorbar(positions[0], [micro_f1_3[0], macro_f1_3[0]], )
# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Micro-F1")# (% gain)")
ax.set_xticks(x)
ax.set_xticklabels(scores)
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)
# plt.ylim(60,100)

# ax.set_yticklabels([60,70,80,90,100])
# # Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'a', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside


ax.set_ylim(70,100)
plt.savefig('fig2_micro_offset.png',dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2> including gemini and claude

# %%
# Out:
# array([0, 1])

# %%
positions_gc
# Out:
# [1.9, 2.1]

# %%
gemini = { 'matsci':{'micro': 51.244,
                     'macro': 45.381},
          'english' : {'micro':82.8325,
                       'macro':78.6725}
         }

claude = { 'matsci':{'micro': 35.995,
                     'macro': 33.179},
          'english' : {'micro':69.6875,
                       'macro':63.5825}
         }

# %%
micro_f1_3
# Out:
# [92.394, 89.611, 84.715, 88.81]

# %%
positions
# Out:
# [array([-0.3,  0.7,  1.7]),
#  array([-0.1,  0.9,  1.9]),
#  array([0.1, 1.1, 2.1]),
#  array([0.3, 1.3, 2.3])]

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]


micro_f1_3 = [92.394, 89.611, 84.715, 88.81]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [92.207, 91.614, 91.162, 91.33] 


macro_f1_2_std_l3 = [0.659, 0.697, 0.735, 1.189]
micro_f1_2_std_l3 = [0.312, 0.535, 0.378, 0.739]

macro_f1_2_std_l2 = [0.494, 0.735, 0.491,0.778]
micro_f1_2_std_l2 = [0.325,  0.36,  0.26, 0.402]


llama3_chat_noft_Macro_f1 = 0 #29.532
llama3_chat_noft_Micro_f1 = 0 #34.738

llama2_chat_noft_Macro_f1 = 0 #12.88
llama2_chat_noft_Micro_f1 = 0 #15.294

# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]
# scores = ['LLaMA-3', 'LLaMA-2', 'Close-Source Models']

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]


positions_gc = [
    2 - 0.5 * bar_width,  # gemini
    2 + 0.5 * bar_width,  # claude 
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

# Lighter pink shades
pinks = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
lighter_pinks = ["#FCE4EC", "#FAD1E7", "#F6A5C9", "#F48FB1", "#F06292", "#EC9BAA", "#E391A0", "#D97896", "#CF607C", "#C54668"]

# Lighter blue shades
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
lighter_blues = ["#E3F2FD", "#BBDEFB", "#90CAF9", "#64B5F6", "#42A5F5", "#1E88E5", "#1565C0", "#2196F3", "#82B1FF", "#B3E5FC"]


news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0] - llama3_chat_noft_Micro_f1, macro_f1_3[0] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[0], micro_f1_2_std_l2[0]], ec='k', label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1] - llama3_chat_noft_Micro_f1, macro_f1_3[1] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[1], micro_f1_2_std_l2[1]], ec='k', label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2] - llama3_chat_noft_Micro_f1, macro_f1_3[2] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[2], micro_f1_2_std_l2[2]], ec='k', label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3] - llama3_chat_noft_Micro_f1, macro_f1_3[3] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[3], micro_f1_2_std_l2[3]], ec='k', label="LLaMA-FT", color=pinks[-1])

ax.bar(positions_gc[0], [claude['matsci']['micro']], bar_width, ec='k', label="Claude-3\nHaiku", color='#FFD54F')
ax.bar(positions_gc[1], [gemini['matsci']['micro']], bar_width, ec='k', label="Gemini-1.5\nFlash-8B", color='#81C784')


# ax.bar(positions_gc[0], [micro_f1_3[3] - llama3_chat_noft_Micro_f1, macro_f1_3[3] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[3], micro_f1_2_std_l2[3]], ec='k', label="LLaMA-FT", color=pinks[-1])

# ax.errorbar(positions[0], [micro_f1_3[0], macro_f1_3[0]], )
# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Micro-F1")# (% gain)")
ax.set_xticks([0,1,2])
ax.set_xticklabels(scores+['Closed\nsource'])
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)
# plt.ylim(60,100)

# ax.set_yticklabels([60,70,80,90,100])
# # Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'a', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside


ax.set_ylim(30,100)
plt.savefig('fig2_micro_offset.png',dpi=600, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]

# ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
# LLaMa, LLaMat, LLaMat-Chat, and LLaMA-Chat-F
micro_f1_3 = [87.414, 83.883, 78.406, 82.742]
# macro_f1_3 = [87.414, 83.883, 78.406, 82.742]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [87.096, 86.414, 85.866, 85.533]
# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0], macro_f1_3[0]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[0], macro_f1_2_std_l2[0]], label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1], macro_f1_3[1]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[1], macro_f1_2_std_l2[1]], label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2], macro_f1_3[2]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[2], macro_f1_2_std_l2[2]], label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3], macro_f1_3[3]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[3], macro_f1_2_std_l2[3]], label="LLaMA-FT", color=pinks[-1])


# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Macro-F1")
ax.set_xticks(x)
ax.set_xticklabels(scores)

ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)



# Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'b', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside

ax.set_ylim(60,100)

plt.savefig('fig2_legend_b-macro.png',dpi=600, bbox_inches='tight')

# ax.set_yticklabels([0, 60, 80, 100])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]

# ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
# LLaMa, LLaMat, LLaMat-Chat, and LLaMA-Chat-F
micro_f1_3 = [87.414, 83.883, 78.406, 82.742]
# macro_f1_3 = [87.414, 83.883, 78.406, 82.742]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [87.096, 86.414, 85.866, 85.533]
# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

positions_gc = [
    2 - 0.5 * bar_width,  # gemini
    2 + 0.5 * bar_width,  # claude 
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0], macro_f1_3[0]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[0], macro_f1_2_std_l2[0]], label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1], macro_f1_3[1]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[1], macro_f1_2_std_l2[1]], label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2], macro_f1_3[2]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[2], macro_f1_2_std_l2[2]], label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3], macro_f1_3[3]], bar_width, ec='k', yerr= [macro_f1_2_std_l3[3], macro_f1_2_std_l2[3]], label="LLaMA-FT", color=pinks[-1])

ax.bar(positions_gc[0], [claude['matsci']['macro']], bar_width, ec='k', label="Claude-3\nHaiku", color='#FFD54F')
ax.bar(positions_gc[1], [gemini['matsci']['macro']], bar_width, ec='k', label="Gemini-1.5\nFlash-8B", color='#81C784')


# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Macro-F1")
# ax.set_xticks(x)
# ax.set_xticklabels(scores)
ax.set_xticks([0,1,2])
ax.set_xticklabels(scores+['Closed\nsource'])
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)



# Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'b', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside

ax.set_ylim(30,100)

plt.savefig('fig2_legend_b-macro.png',dpi=600, bbox_inches='tight')

# ax.set_yticklabels([0, 60, 80, 100])

plt.show()

# %% [markdown]
# <h2> performance gain macro

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]

# ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
# LLaMa, LLaMat, LLaMat-Chat, and LLaMA-Chat-F
micro_f1_3 = [87.414, 83.883, 78.406, 82.742]
# macro_f1_3 = [87.414, 83.883, 78.406, 82.742]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [87.096, 86.414, 85.866, 85.533]
# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news

llama3_chat_noft_Macro_f1 = 0 #29.532
llama3_chat_noft_Micro_f1 = 0 #34.738

llama2_chat_noft_Macro_f1 = 0 #12.88
llama2_chat_noft_Micro_f1 = 0 #15.294


# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0]-llama3_chat_noft_Macro_f1, macro_f1_3[0] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[0], macro_f1_2_std_l2[0]], label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1]-llama3_chat_noft_Macro_f1, macro_f1_3[1] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[1], macro_f1_2_std_l2[1]], label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2]-llama3_chat_noft_Macro_f1, macro_f1_3[2] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[2], macro_f1_2_std_l2[2]], label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3]-llama3_chat_noft_Macro_f1, macro_f1_3[3] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[3], macro_f1_2_std_l2[3]], label="LLaMA-FT", color=pinks[-1])

# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Macro-F1")# (% gain)")
ax.set_xticks(x)
ax.set_xticklabels(scores)
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)

# ax.set_yticklabels([0,75, 80, 85, 90])
# Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'b', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside
# bax = brokenaxes(ylims=((0, 5), (65, 95)), hspace=0.25)
# plt.savefig('fig2_legend_b_pi_macro.png',dpi=600, bbox_inches='tight')
ax.set_ylim(70,100)

plt.savefig('fig2_macro_offset.png',dpi=600, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]

# ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
# LLaMa, LLaMat, LLaMat-Chat, and LLaMA-Chat-F
micro_f1_3 = [87.414, 83.883, 78.406, 82.742]
# macro_f1_3 = [87.414, 83.883, 78.406, 82.742]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [87.096, 86.414, 85.866, 85.533]
# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0], macro_f1_3[0]], bar_width, ec='k', label="LLaMat-chat", color=cids[0]) 
ax.bar(positions[1], [micro_f1_3[1], macro_f1_3[1]], bar_width, ec='k', label="LLaMat", color=cids[1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2], macro_f1_3[2]], bar_width, ec='k', label="LLaMA-chat-FT", color=cids[2])
ax.bar(positions[3], [micro_f1_3[3], macro_f1_3[3]], bar_width, ec='k', label="LLaMA-FT", color=cids[3])

# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Macro-F1")
ax.set_xticks(x)
ax.set_xticklabels(scores)
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)
plt.ylim(70,90)

ax.set_yticklabels([0,75, 80, 85, 90])
# Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'c', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside
# bax = brokenaxes(ylims=((0, 5), (65, 95)), hspace=0.25)
plt.savefig('fig2_legend_c.png',dpi=600, bbox_inches='tight')

plt.show()
# Out:
# <ipython-input-334-96f18557c13a>:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0,75, 80, 85, 90])

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat", "LLaMA"]

# ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
# LLaMa, LLaMat, LLaMat-Chat, and LLaMA-Chat-F
micro_f1_3 = [87.414, 83.883, 78.406, 82.742]
# macro_f1_3 = [87.414, 83.883, 78.406, 82.742]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [87.096, 86.414, 85.866, 85.533]
# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

# Lighter pink shades
pinks = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
lighter_pinks = ["#FCE4EC", "#FAD1E7", "#F6A5C9", "#F48FB1", "#F06292", "#EC9BAA", "#E391A0", "#D97896", "#CF607C", "#C54668"]

# Lighter blue shades
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
lighter_blues = ["#E3F2FD", "#BBDEFB", "#90CAF9", "#64B5F6", "#42A5F5", "#1E88E5", "#1565C0", "#2196F3", "#82B1FF", "#B3E5FC"]


news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0], macro_f1_3[0]], bar_width, ec='k', label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1], macro_f1_3[1]], bar_width, ec='k', label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2], macro_f1_3[2]], bar_width, ec='k', label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3], macro_f1_3[3]], bar_width, ec='k', label="LLaMA-FT", color=pinks[-1])

finalcolors = ['#64B5F6', blues[-1], '#F06292', pinks[-1]]
# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Macro-F1")
ax.set_xticks(x)
ax.set_xticklabels(scores)
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)
plt.ylim(70,90)

ax.set_yticklabels([0,75, 80, 85, 90])
# Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'b', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside
# bax = brokenaxes(ylims=((0, 5), (65, 95)), hspace=0.25)
# plt.savefig('fig2_legend.png',dpi=600, bbox_inches='tight')

plt.show()
# Out:
# <ipython-input-338-78cad383517b>:71: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0,75, 80, 85, 90])

# %%
import matplotlib.pyplot as plt

# Define color lists
pinks = ["#FCE4EC", "#FAD1E7", "#F6A5C9", "#F48FB1", "#F06292", 
         "#EC9BAA", "#E391A0", "#D97896", "#CF607C", "#C54668"]

blues = ["#E3F2FD", "#BBDEFB", "#90CAF9", "#64B5F6", "#42A5F5", 
         "#1E88E5", "#1565C0", "#2196F3", "#82B1FF", "#B3E5FC"]

# Create subplots for pinks and blues
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Pink bar plot
axs[0].bar(range(len(pinks)), [1]*len(pinks), color=pinks)
axs[0].set_xticks(range(len(pinks)))
axs[0].set_xticklabels(pinks, rotation=45, fontsize=9)
axs[0].set_title("Lighter Shades of Pink")
axs[0].set_yticks([])

# Blue bar plot
axs[1].bar(range(len(blues)), [1]*len(blues), color=blues)
axs[1].set_xticks(range(len(blues)))
axs[1].set_xticklabels(blues, rotation=45, fontsize=9)
axs[1].set_title("Lighter Shades of Blue")
axs[1].set_yticks([])

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>english micro

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]


micro_f1_3 = [87.3, 86.227, 87.145, 87.602] #[92.394, 89.611, 84.715, 88.81]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [86.727, 85.245, 86.338, 86.517] #[92.207, 91.614, 91.162, 91.33] 


macro_f1_2_std_l3 = [0.4525, 0.455, 0.58, 0.6525] #[0.659, 0.697, 0.735, 1.189]
micro_f1_2_std_l3 = [0.4725, 0.4125, 0.5475, 0.4925] #[0.312, 0.535, 0.378, 0.739]

macro_f1_2_std_l2 = [0.5  , 0.3525, 0.5375, 0.58] #[0.494, 0.735, 0.491,0.778]
micro_f1_2_std_l2 = [0.435, 0.3625, 0.5175, 0.5925] #[0.325,  0.36,  0.26, 0.402]


llama3_chat_noft_Macro_f1 = 0 #28.9075 #29.532
llama3_chat_noft_Micro_f1 = 0 #40.63 #34.738

llama2_chat_noft_Macro_f1 = 0 #27.0625 #12.88
llama2_chat_noft_Micro_f1 = 0 #42.7825 #15.294

# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

# Lighter pink shades
pinks = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
lighter_pinks = ["#FCE4EC", "#FAD1E7", "#F6A5C9", "#F48FB1", "#F06292", "#EC9BAA", "#E391A0", "#D97896", "#CF607C", "#C54668"]

# Lighter blue shades
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
lighter_blues = ["#E3F2FD", "#BBDEFB", "#90CAF9", "#64B5F6", "#42A5F5", "#1E88E5", "#1565C0", "#2196F3", "#82B1FF", "#B3E5FC"]


news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news

positions_gc = [
    2 - 0.5 * bar_width,  # gemini
    2 + 0.5 * bar_width,  # claude 
]

# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0] - llama3_chat_noft_Micro_f1, macro_f1_3[0] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[0], micro_f1_2_std_l2[0]], ec='k', label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1] - llama3_chat_noft_Micro_f1, macro_f1_3[1] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[1], micro_f1_2_std_l2[1]], ec='k', label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2] - llama3_chat_noft_Micro_f1, macro_f1_3[2] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[2], micro_f1_2_std_l2[2]], ec='k', label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3] - llama3_chat_noft_Micro_f1, macro_f1_3[3] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[3], micro_f1_2_std_l2[3]], ec='k', label="LLaMA-FT", color=pinks[-1])
ax.bar(positions_gc[0], [claude['english']['micro']], bar_width, ec='k', label="Claude-3\nHaiku", color='#FFD54F')
ax.bar(positions_gc[1], [gemini['english']['micro']], bar_width, ec='k', label="Gemini-1.5\nFlash-8B", color='#81C784')


# ax.errorbar(positions[0], [micro_f1_3[0], macro_f1_3[0]], )
# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Micro-F1")# (% gain)")
# ax.set_xticks(x)
# ax.set_xticklabels(scores)

ax.set_xticks([0,1,2])
ax.set_xticklabels(scores+['Closed\nsource'])

ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)
# plt.ylim(60,100)

# ax.set_yticklabels([60,70,80,90,100])
# # Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'c', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside

ax.set_ylim(60,100)
# ax.set_ylim(70,100)
plt.savefig('fig2_c_micro_english.png',dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2>english macro

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]

# ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
# LLaMa, LLaMat, LLaMat-Chat, and LLaMA-Chat-F
micro_f1_3 = [82.855, 81.9, 82.915, 83.29] #[87.414, 83.883, 78.406, 82.742]
# macro_f1_3 = [87.414, 83.883, 78.406, 82.742]


# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [82.178, 80.845, 82.007, 82.22] #[87.096, 86.414, 85.866, 85.533]
# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]


macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news

llama3_chat_noft_Macro_f1 = 0 #28.9075 #29.532
llama3_chat_noft_Micro_f1 = 0 #40.63 #34.738

llama2_chat_noft_Macro_f1 = 0 #27.0625 #12.88
llama2_chat_noft_Micro_f1 = 0 #42.7825 #15.294


positions_gc = [
    2 - 0.5 * bar_width,  # gemini
    2 + 0.5 * bar_width,  # claude 
]


# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0]-llama3_chat_noft_Macro_f1, macro_f1_3[0] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[0], macro_f1_2_std_l2[0]], label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1]-llama3_chat_noft_Macro_f1, macro_f1_3[1] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[1], macro_f1_2_std_l2[1]], label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2]-llama3_chat_noft_Macro_f1, macro_f1_3[2] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[2], macro_f1_2_std_l2[2]], label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3]-llama3_chat_noft_Macro_f1, macro_f1_3[3] -llama2_chat_noft_Macro_f1], bar_width, ec='k', yerr= [macro_f1_2_std_l3[3], macro_f1_2_std_l2[3]], label="LLaMA-FT", color=pinks[-1])
ax.bar(positions_gc[0], [claude['english']['macro']], bar_width, ec='k', label="Claude-3\nHaiku", color='#FFD54F')
ax.bar(positions_gc[1], [gemini['english']['macro']], bar_width, ec='k', label="Gemini-1.5\nFlash-8B", color='#81C784')


# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Macro-F1")# (% gain)")
# ax.set_xticks(x)
# ax.set_xticklabels(scores)
ax.set_xticks([0,1,2])
ax.set_xticklabels(scores+['Closed\nsource'])
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)

# ax.set_yticklabels([0,75, 80, 85, 90])
# Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'd', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside
# bax = brokenaxes(ylims=((0, 5), (65, 95)), hspace=0.25)
# plt.savefig('fig2_legend_b_pi_macro.png',dpi=600, bbox_inches='tight')
ax.set_ylim(60,100)

plt.savefig('fig2_d_macro_english.png',dpi=600, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

set_font(size=30, weight="normal")
# Data for LLAMA-3
categories = ["LLaMat-chat", "LLaMat", "LLaMA-chat-FT", "LLaMA-FT"]


micro_f1_3 = [87.3, 86.227, 87.145, 87.602] #[92.394, 89.611, 84.715, 88.81]

# Data for LLAMA-2
categories = ["Chat", "Base", "Chat (finetuned)", "Base (finetuned)"]
micro_f1_2 = [86.727, 85.245, 86.338, 86.517] #[92.207, 91.614, 91.162, 91.33] 


macro_f1_2_std_l3 = [0.4525, 0.455, 0.58, 0.6525] #[0.659, 0.697, 0.735, 1.189]
micro_f1_2_std_l3 = [0.4725, 0.4125, 0.5475, 0.4925] #[0.312, 0.535, 0.378, 0.739]

macro_f1_2_std_l2 = [0.5  , 0.3525, 0.5375, 0.58] #[0.494, 0.735, 0.491,0.778]
micro_f1_2_std_l2 = [0.435, 0.3625, 0.5175, 0.5925] #[0.325,  0.36,  0.26, 0.402]


llama3_chat_noft_Macro_f1 = 0 #28.9075 #29.532
llama3_chat_noft_Micro_f1 = 0 #40.63 #34.738

llama2_chat_noft_Macro_f1 = 0 #27.0625 #12.88
llama2_chat_noft_Micro_f1 = 0 #42.7825 #15.294

# macro_f1_3 = [87.096, 86.414, 85.866, 85.533]

macro_f1_3 = micro_f1_2

# X-axis labels
scores = ["LLaMA-3", "LLaMA-2"]

# Grouped bar graph settings
x = np.arange(len(scores))  # X positions for Micro-F1 and Macro-F1
bar_width = 0.2  # Width of each bar

# Shift positions for each category
positions = [
    x - 1.5 * bar_width,  # Chat
    x - 0.5 * bar_width,  # Base
    x + 0.5 * bar_width,  # Chat (finetuned)
    x + 1.5 * bar_width,  # Base (finetuned)
]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

pinks  = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
orange = ["#E65100", "#FB8C00", "#FFB74D", "#FFE0B2"]
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
teals = ["#004D40", "#00796B", "#26A69A", "#B2DFDB"]

# Lighter pink shades
pinks = ["#880E4F", "#C2185B", "#E91E63", "#F8BBD0"]
lighter_pinks = ["#FCE4EC", "#FAD1E7", "#F6A5C9", "#F48FB1", "#F06292", "#EC9BAA", "#E391A0", "#D97896", "#CF607C", "#C54668"]

# Lighter blue shades
blues = ["#0D47A1", "#1976D2", "#42A5F5", "#BBDEFB"]
lighter_blues = ["#E3F2FD", "#BBDEFB", "#90CAF9", "#64B5F6", "#42A5F5", "#1E88E5", "#1565C0", "#2196F3", "#82B1FF", "#B3E5FC"]


news = [blues[-1], pinks[-1], teals[-1], orange[-1]]
cids =  news
# Plot bars for each category
ax.bar(positions[0], [micro_f1_3[0] - llama3_chat_noft_Micro_f1, macro_f1_3[0] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[0], micro_f1_2_std_l2[0]], ec='k', label="LLaMat-chat", color='#64B5F6') 
ax.bar(positions[1], [micro_f1_3[1] - llama3_chat_noft_Micro_f1, macro_f1_3[1] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[1], micro_f1_2_std_l2[1]], ec='k', label="LLaMat", color=blues[-1]) #1E88E5
ax.bar(positions[2], [micro_f1_3[2] - llama3_chat_noft_Micro_f1, macro_f1_3[2] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[2], micro_f1_2_std_l2[2]], ec='k', label="LLaMA-chat-FT", color='#F06292')
ax.bar(positions[3], [micro_f1_3[3] - llama3_chat_noft_Micro_f1, macro_f1_3[3] - llama2_chat_noft_Micro_f1], bar_width, yerr= [micro_f1_2_std_l3[3], micro_f1_2_std_l2[3]], ec='k', label="LLaMA-FT", color=pinks[-1])

# ax.errorbar(positions[0], [micro_f1_3[0], macro_f1_3[0]], )
# Customize the plot
# ax.set_title("LLAMA-3 Scores (Micro-F1 and Macro-F1)", fontsize=20)
ax.set_xlabel("Base model")
ax.set_ylabel("Micro-F1")# (% gain)")
ax.set_xticks(x)
ax.set_xticklabels(scores)
ax.legend( title_fontsize=20, loc=[1, 0.1])
ax.grid(axis="y", linestyle="--", alpha=0.7)
# plt.ylim(60,100)

# ax.set_yticklabels([60,70,80,90,100])
# # Adjust layout and display
plt.tight_layout()
plt.text(-0.22, 1, 'c', transform=ax.transAxes, fontweight='bold')
# plt.title('LLMat-3 and LLaMA-3\n')
ax.spines['top'].set_visible(False)  # Disable the top axis
ax.spines['right'].set_visible(False)  # Disable the left axis
ax.yaxis.set_ticks_position('left')  # Remove left (y-axis) ticks
ax.xaxis.set_ticks_position('bottom')  # Remove top (x-axis) ticks

ax.tick_params(axis='x', which='both', direction='out')  # Move x-axis ticks outside
ax.tick_params(axis='y', which='both', direction='out')  # Move y-axis ticks outside

ax.set_title('MatNLP')
# ax.set_ylim(0,100)
# ax.set_ylim(60,100)
plt.savefig('fig2_c_gain_micro_MatNLP_title.png',dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h1> spider

# %%
import ast

# %%
labels  = [
    "('ner', 'matscholar')", 
    "('ner', 'sofc_token')", 
    "('ner', 'sc_comics')", 
    "('class', 'glass_non_glass')", 
    "('ner', 'sofc_token-2')", 
    "('ee', 'sc_comics')", 
    "('re', 'structured_re')", 
    "('re', 'sc_comics')", 
    "('class', 'synthesis_actions')", 
    "('class', 'sofc_sent')", 
    "('qna', 'squad')", 
    "('mcq', 'hellaswag')", 
    "('mcq', 'boolqa')", 
    "('mcq', 'story_cloze')"
]
labels = [ast.literal_eval(l) for l in labels]

prefix = [l[0] for l in labels]
datasets = [l[1] for l in labels]

# %%
labels  = [
    "('ner', 'matscholar')", 
    "('ner', 'sofc_token-1')", 
    "('ner', 'sc_comics-1')", 
    "('class', 'glass_non_glass')", 
    "('ner', 'sofc_token-2')", 
    "('ee', 'sc_comics-2')", 
    "('re', 'structured_re')", 
    "('re', 'sc_comics-3')", 
    "('class', 'synthesis_actions')", 
    "('class', 'sofc_sent')", 
    "('qna', 'squad')", 
    "('mcq', 'hellaswag')", 
    "('mcq', 'boolqa')", 
    "('mcq', 'story_cloze')"
]

# %%
Entity Recognition & Matscholar & 86.97 & 81.72 & 83.4 & 81.13 & 81.74 & 81.46 & 80.63 & 80.75 \\
Entity Recognition & SOFC-1  & 89.73 & 87.16 & 89.45 & 88.06 & 89.3 & 87.59 & 86.27 & 88.42 \\
Entity Recognition & SOFC-2  & 83.28 & 77.95 & 76.79 & 77.37 & 81.98 & 81.26 & 80.56 & 80.14 \\
Entity Recognition & SC-CoMIcs-1  & 90.73 & 86.74 & 70.87 & 89.03 & 91.31 & 90.9 & 90.67 & 90.93 \\
Classification & Glass   & 92.56 & 90.89 & 89.67 & 85.11 & 93.67 & 91.33 & 92.89 & 91.56 \\
Classification & Synthesis Actions  & 96.68 & 95.33 & 94.9 & 95.75 & 96.44 & 96.1 & 96.16 & 96.04 \\
Classification & SOFC-3  & 93.24 & 92.52 & 92.68 & 92.09 & 93.85 & 93.26 & 93.19 & 93.2 \\
Entity Extraction & SC-CoMIcs-2  & 91.95 & 91.22 & 66.38 & 86.26 & 93.78 & 94.4 & 91.33 & 92.34 \\
Entity Extraction & SC-CoMIcs-3  & 98.8 & 92.58 & 83.01 & 93.3 & 100.0 & 99.84 & 99.92 & 99.92 \\
Entity Extraction & MatSci  & 100.0 & 100.0 & 100.0 & 100.0 & 100.0 & 100.0 & 100.0 & 100.0 \\

# %%
['matscholar','sofc_token-1', 'sofc_token-2', 'sc_comics-1']
['glass_non_glass', 'synthesis_actions','sofc_sent']

# %%
# \textbf{MatNLP} & & & & \\
# \midrule
# \textbf{Entity recognition} & & & & \\
# Matscholar & Matscholar & 1062 & 1061 & Named entity recognition tasks over data taken from matscholar. \\
# SOFC-1 & sofc-token & 175 & 177 & Named entity recognition over sentences from a corpus with data pertaining to "solid oxide fuel cells" \cite{friedrich2020sofc} \\
# SOFC-2 & sofc-token  & 175 & 179 & Identify slot fillers from sentences using a predefined set of semantically meaningful entities. Each sentence describes an experiment frame. \\
# SC-CoMIcs-1 & sc-comics & 937 & 936 & Named entity recognition over sentences from a corpus on "superconductivity" \cite{yamaguchi2020sc}. \
# \\
# \textbf{Classification} & & & & \\
# Glass & glass-non-glass & 300 & 299 & Paragraph classification: Determine whether a given paragraph pertains to glass science. This task is adapted from \cite{venugopal2021looking} \\
# Synthesis Actions & SAR & 565 & 569 & Classify word tokens into one of eight predefined synthesis action categories. SAR data adapted from \cite{wang2022ulsa}\\
# SOFC-3 & sofc-sent & 1893 & 1889 & Sentence classification: Identify sentences that describe relevant experimental facts. The task data is adapted from \cite{friedrich2020sofc} \\
# \textbf{Extraction} & & & & \\
# SC-CoMIcs-2 & sc-comics & 287 & 288 & Extract event arguments and their roles based on specified event triggers. \\
# SC-CoMIcs-3 & sc-comics & 376 & 373 & Predict the most relevant relation type for a given span pair. \\
# MatSci & structured-re & 1788 & 1786 & Predict the most relevant relation type for a given span pair. \\

# \midrule

# %%
ner = ['matscholar','sofc_token-1', 'sofc_token-2', 'sc_comics-1']
classification = ['glass_non_glass', 'synthesis_actions','sofc_sent'] 
extraction = ['sc_comics-2','sc_comics-3','structured_re']

# %%
print(datasets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-d6a8f7866d6d> in <module>
# ----> 1 print(datasets)
#
# NameError: name 'datasets' is not defined

# %%
matsci  = ['matscholar', 'sofc_token', 'sc_comics', 'glass_non_glass', 'sofc_token', 'sc_comics', 'structured_re', 'sc_comics', 'synthesis_actions', 'sofc_sent'] 
english = ['squad', 'hellaswag', 'boolqa', 'story_cloze']

macro_f1s = [76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38, 66.56, 80.67, 83.08, 98.4]
macro_std = [0.68, 0.88, 0.11, 0.74, 0.65, 0.6, 0.0, 0.0, 0.12, 1.16, 0.35, 0.84, 0.81, 0.0]

micro_f1s = [81.74, 89.3, 91.31, 93.67, 81.98, 93.78, 100.0, 100.0, 96.44, 93.85, 84.24, 80.67, 83.6, 98.4]
micro_std = [0.35, 1.1, 0.09, 0.67, 0.44, 0.32, 0.0, 0.0, 0.11, 0.17, 0.16, 0.86, 0.72, 0.0]

# %%
print(prefix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-c5322aedc34a> in <module>
# ----> 1 print(prefix)
#
# NameError: name 'prefix' is not defined

# %%
matsci  = ['matscholar', 'sofc_token', 'sc_comics', 'glass_non_glass', 'sofc_token', 'sc_comics', 'structured_re', 'sc_comics', 'synthesis_actions', 'sofc_sent']
cats =    ['ner',         'ner',           'ner',          'pc',            'sf',        'ee',           're',          're',              'sar',          'sc' ]

macro_f1_dict = {'LLaMat-chat':[76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38, 66.56, 80.67, 83.08, 98.4],
                 'LLaMat': [75.82, 77.78, 86.84, 91.58, 71.83, 90.2, 99.0, 99.0, 93.53, 75.38, 65.56, 79.67, 82.08, 97.4],
                 'LLaMA-chat':[ 72.82, 74.78, 83.84, 88.58, 68.83, 87.2, 96.0, 96.0, 90.53, 72.38, 62.56, 76.67, 79.08, 94.4],
                 'LLaMA': [70.82, 72.78, 81.84, 86.58, 66.83, 85.2, 94.0, 94.0, 88.53, 70.38, 60.56, 74.67, 77.08, 92.4]}

# %%
set_font(size=30,weight='normal')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
matsci = ['matscholar', 'sofc_token', 'sc_comics', 'glass_non_glass', 
          'sofc_token', 'sc_comics', 'structured_re', 'sc_comics', 
          'synthesis_actions', 'sofc_sent']

macro_f1_dict = {
    'LLaMat-chat': [76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38],
    'LLaMat': list(np.array([75.82, 77.78, 86.84, 91.58, 71.83, 90.2, 99.0, 99.0, 93.53, 75.38])+10),
    'LLaMA-chat': [72.82, 74.78, 83.84, 88.58, 68.83, 87.2, 96.0, 96.0, 90.53, 72.38],
    'LLaMA': [70.82, 72.78, 81.84, 86.58, 66.83, 85.2, 94.0, 94.0, 88.53, 70.38]
}

# finalcolors = ['#BBDEFB', '#64B5F6' , '#F06292', '#F8BBD0']


finalcolors = ['#BBDEFB', '#64B5F6' , '#F06292', '#F8BBD0']
lss = ['-','-','-','-']

# Prepare data for radar chart
categories = matsci
num_vars = len(categories)

# Angle for each category
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# Complete the loop by appending the start angle to close the radar chart
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plot each model's data
cid = 0
for model, scores in macro_f1_dict.items():
    data = scores + scores[:1]  # Close the loop
    ax.plot(angles, data, label=model, linewidth=2, c = finalcolors[cid], ls=lss[cid])
#     ax.fill(angles, data, alpha=0.25,c=finalcolors[cid])
    cid += 1
    

# Add labels
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)

# Set the category labels
ax.set_xticks(angles[:-1])
# ax.set_xticklabels(categories)

ax.set_xticklabels([])

# Set the radial labels
ax.set_rlabel_position(0)
ax.set_yticks([0,20,40,60,80,100])  # Customize as needed
ax.set_yticklabels([])
# ax.set_ylim(50, 100)
# ax.spines['polar'].set_visible(True)
# ax.set_frame_on(True)
for spine in ax.spines.values():
    spine.set_edgecolor('lightgrey')
    
plt.grid(color='lightgrey', alpha=0.5)

ax.spines['polar'].set_linewidth(1)  # Remove circular frame
ax.set_rgrids([50, 70, 90, 100], angle=0)  # Add radial grid lines as straight lines


# Title and legend
# plt.title('Macro-F1 Scores Radar Chart', size=16, y=1.1)
# ax.legend(loc='upper right', bbox_to_anchor=(1.2, 1.1))
# plt.savefig('fig_2_spider.png',bbox_inches='tight',dpi=1200)
plt.show()

# %%
for x in ax.spines.values():
    print(x)
# Out:
# Spine
# Spine
# Spine
# Spine

# %%
set_font(size=30,weight='normal')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
# matsci = ['Matscholar (NER)', 'SOFC-1 (NER)', 'SC-\nCoMIcs (NER)', 'Glass (PC)', 
#           'SOFC (SF)', 'SC-CoMIcs (EE)', 'MatSci (RE)', 'SC-\nCoMIcs (RE)', 
#           'Synthesis\nActions (SAR)', 'SOFC (SC)']

matsci = ['Matscholar (NER)', 'SOFC-1', 'SOFC-2', 'SC-CoMIcs-1', 
          'Glass', 'Synthesis\nActions', 'SOFC-3',
          'SC-CoMIcs-2', 'SC-CoMIcs-3', 'MatSci']

#           'SOFC (SF)', 'SC-CoMIcs (EE)', 'MatSci (RE)', 'SC-\nCoMIcs (RE)', 
#           (SAR)', 'SOFC (SC)']


ner = ['matscholar','sofc_token-1', 'sofc_token-2', 'sc_comics-1']
classification = ['glass_non_glass', 'synthesis_actions','sofc_sent'] 
extraction = ['sc_comics-2','sc_comics-3','structured_re']


macro_f1_dict = {
    'LLaMat-chat': [76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38],
    'LLaMat': list(np.array([75.82, 77.78, 86.84, 91.58, 71.83, 90.2, 99.0, 99.0, 93.53, 75.38])+10),
    'LLaMA-chat': [72.82, 74.78, 83.84, 88.58, 68.83, 87.2, 96.0, 96.0, 90.53, 72.38],
    'LLaMA': [70.82, 72.78, 81.84, 86.58, 66.83, 85.2, 94.0, 94.0, 88.53, 70.38]
}

finalcolors = ['#64B5F6', '#BBDEFB', '#F06292', '#F8BBD0']


# Prepare data for radar chart
categories = matsci
num_vars = len(categories)

# Angle for each category
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# Complete the loop by appending the start angle to close the radar chart
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plot each model's data
cid = 0
for model, scores in macro_f1_dict.items():
    data = scores + scores[:1]  # Close the loop
    ax.plot(angles, data, label=model, linewidth=2, c = finalcolors[cid])
    cid += 1
#     ax.fill(angles, data, alpha=0.25)

# Add labels
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)

# Set the category labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)

# ax.set_xticklabels([])

# Set the radial labels
ax.set_rlabel_position(0)
ax.set_yticks([0,20,40,60,80,100])  # Customize as needed
ax.set_yticklabels([])
# ax.set_ylim(50, 100)
ax.spines['polar'].set_visible(False)
ax.tick_params(pad=100)  # Adjust padding value as needed

# Title and legend
# plt.title('Macro-F1 Scores Radar Chart', size=16, y=1.1)
# ax.legend(loc='upper right', bbox_to_anchor=(1.2, 1.1))
# plt.savefig('fig_2_spider_labels.png',bbox_inches='tight',dpi=1200)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
matsci = ['matscholar', 'sofc_token', 'sc_comics', 'glass_non_glass', 
          'sofc_token', 'sc_comics', 'structured_re', 'sc_comics', 
          'synthesis_actions', 'sofc_sent']

macro_f1_dict = {
    'LLaMat-chat': [76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38],
    'LLaMat': [75.82, 77.78, 86.84, 91.58, 71.83, 90.2, 99.0, 99.0, 93.53, 75.38],
    'LLaMA-chat': [72.82, 74.78, 83.84, 88.58, 68.83, 87.2, 96.0, 96.0, 90.53, 72.38],
    'LLaMA': [70.82, 72.78, 81.84, 86.58, 66.83, 85.2, 94.0, 94.0, 88.53, 70.38]
}

# Number of variables
num_vars = len(matsci)

# Angles for the radar
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # Close the loop

# Initialize plot
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Custom radial grid to make it polygonal
ax.set_rgrids([])  # Remove the default circular grid
for r in [20, 30, 50, 70, 90, 100,110]:
    values = [r] * num_vars + [r]  # Close the loop
    ax.plot(angles, values, color="gray", linestyle="dotted", linewidth=0.8)

# Plot each model's data
for model, scores in macro_f1_dict.items():
    data = scores[:num_vars] + scores[:1]  # Close the loop
    ax.plot(angles, data, label=model, linewidth=2)
#     ax.fill(angles, data, alpha=0.25)

# Set category labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(matsci, fontsize=10)

# Customize radial limits
ax.set_ylim(50, 110)
ax.set_yticklabels([])  # Remove radial labels if not needed

# Title and legend
plt.title('Polygonal Radar Chart for Macro-F1 Scores', size=16, y=1.1)
# ax.legend(loc='upper right', bbox_to_anchor=(1.2, 1.1))
# Make the frame polygonal (remove circular spine and use straight lines)
ax.spines['polar'].set_visible(False)  # Remove the circular frame
ax.set_frame_on(True)  # Make sure the frame is visible

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import RegularPolygon
from matplotlib.projections import register_projection
from matplotlib.projections.polar import PolarAxes
from matplotlib.spines import Spine
from matplotlib.path import Path
from matplotlib.transforms import Affine2D

# Define radar_factory function
def radar_factory(num_vars, frame='polygon'):
    """
    Create a radar chart with `num_vars` Axes.
    """
    # Calculate evenly spaced axis angles
    theta = np.linspace(0, 2 * np.pi, num_vars, endpoint=False)

    class RadarAxes(PolarAxes):
        name = 'radar'

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            self.set_theta_zero_location('N')

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            # Return polygonal frame
            if frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars, radius=0.5, edgecolor="k")
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

        def _gen_axes_spines(self):
            spine = Spine(axes=self,
                          spine_type='circle',
                          path=Path.unit_regular_polygon(num_vars))
            spine.set_transform(Affine2D().scale(0.5).translate(0.5, 0.5) + self.transAxes)
            return {'polar': spine}

    register_projection(RadarAxes)
    return theta

# Data for the radar chart
matsci = ['matscholar', 'sofc_token', 'sc_comics', 'glass_non_glass', 'sofc_token', 'sc_comics', 'structured_re', 'sc_comics', 'synthesis_actions', 'sofc_sent']
macro_f1_dict = {
    'LLaMat-chat': [76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38],
    'LLaMat': [75.82, 77.78, 86.84, 91.58, 71.83, 90.2, 99.0, 99.0, 93.53, 75.38],
    'LLaMA-chat': [72.82, 74.78, 83.84, 88.58, 68.83, 87.2, 96.0, 96.0, 90.53, 72.38],
    'LLaMA': [70.82, 72.78, 81.84, 86.58, 66.83, 85.2, 94.0, 94.0, 88.53, 70.38]
}

# Set up the radar chart
N = len(matsci)
theta = radar_factory(N, frame='polygon')

# Create the plot
fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(projection='radar'))

# Plot each model's results as a polygon on the radar chart
colors = ['b', 'r', 'g', 'm']
for idx, (label, scores) in enumerate(macro_f1_dict.items()):
    theta = radar_factory(N, frame='polygon')
    theta = list(theta)
    theta += theta[:1]
    scores += scores[:1]
    print(scores)
    ax.plot(theta, scores, color=colors[idx % len(colors)], linewidth=2, label=label)
#     ax.fill(theta, scores, color=colors[idx % len(colors)], alpha=0.25)

# Add labels and title
ax.set_varlabels(matsci)
# ax.set_title('Macro F1 Scores Comparison', size=15, weight='bold', position=(0.5, 1.1), horizontalalignment='center')

# Add legend
# ax.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

plt.show()
# Out:
# [76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38, 76.82]
# [75.82, 77.78, 86.84, 91.58, 71.83, 90.2, 99.0, 99.0, 93.53, 75.38, 75.82]
# [72.82, 74.78, 83.84, 88.58, 68.83, 87.2, 96.0, 96.0, 90.53, 72.38, 72.82]
# [70.82, 72.78, 81.84, 86.58, 66.83, 85.2, 94.0, 94.0, 88.53, 70.38, 70.82]

# %%
scores
# Out:
# [70.82, 72.78, 81.84, 86.58, 66.83, 85.2, 94.0, 94.0, 88.53, 70.38, 70.82]

# %%
theta
# Out:
# [0.0,
#  0.6283185307179586,
#  1.2566370614359172,
#  1.8849555921538759,
#  2.5132741228718345,
#  3.141592653589793,
#  3.7699111843077517,
#  4.39822971502571,
#  5.026548245743669,
#  5.654866776461628,
#  0.0]

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections import register_projection
from matplotlib.projections.polar import PolarAxes
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D


def radar_factory(num_vars, frame='circle'):
    """
    Create a radar chart with `num_vars` Axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle', 'polygon'}
        Shape of frame surrounding Axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarTransform(PolarAxes.PolarTransform):

        def transform_path_non_affine(self, path):
            if path._interpolation_steps > 1:
                path = path.interpolated(num_vars)
            return Path(self.transform(path.vertices), path.codes)

    class RadarAxes(PolarAxes):

        name = 'radar'
        PolarTransform = RadarTransform

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                spine = Spine(axes=self,
                              spine_type='circle',
                              path=Path.unit_regular_polygon(num_vars))
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

    register_projection(RadarAxes)
    return theta


def example_data():
    data = [
        ['Sulfate', 'Nitrate', 'EC', 'OC1', 'OC2', 'OC3', 'OP', 'CO', 'O3'],
        ('Basecase', [
            [0.88, 0.01, 0.03, 0.03, 0.00, 0.06, 0.01, 0.00, 0.00],
            [0.07, 0.95, 0.04, 0.05, 0.00, 0.02, 0.01, 0.00, 0.00],
            [0.01, 0.02, 0.85, 0.19, 0.05, 0.10, 0.00, 0.00, 0.00],
            [0.02, 0.01, 0.07, 0.01, 0.21, 0.12, 0.98, 0.00, 0.00],
            [0.01, 0.01, 0.02, 0.71, 0.74, 0.70, 0.00, 0.00, 0.00]]),
        ('With CO', [
            [0.88, 0.02, 0.02, 0.02, 0.00, 0.05, 0.00, 0.05, 0.00],
            [0.08, 0.94, 0.04, 0.02, 0.00, 0.01, 0.12, 0.04, 0.00],
            [0.01, 0.01, 0.79, 0.10, 0.00, 0.05, 0.00, 0.31, 0.00],
            [0.00, 0.02, 0.03, 0.38, 0.31, 0.31, 0.00, 0.59, 0.00],
            [0.02, 0.02, 0.11, 0.47, 0.69, 0.58, 0.88, 0.00, 0.00]]),
        ('With O3', [
            [0.89, 0.01, 0.07, 0.00, 0.00, 0.05, 0.00, 0.00, 0.03],
            [0.07, 0.95, 0.05, 0.04, 0.00, 0.02, 0.12, 0.00, 0.00],
            [0.01, 0.02, 0.86, 0.27, 0.16, 0.19, 0.00, 0.00, 0.00],
            [0.01, 0.03, 0.00, 0.32, 0.29, 0.27, 0.00, 0.00, 0.95],
            [0.02, 0.00, 0.03, 0.37, 0.56, 0.47, 0.87, 0.00, 0.00]]),
        ('CO & O3', [
            [0.87, 0.01, 0.08, 0.00, 0.00, 0.04, 0.00, 0.00, 0.01],
            [0.09, 0.95, 0.02, 0.03, 0.00, 0.01, 0.13, 0.06, 0.00],
            [0.01, 0.02, 0.71, 0.24, 0.13, 0.16, 0.00, 0.50, 0.00],
            [0.01, 0.03, 0.00, 0.28, 0.24, 0.23, 0.00, 0.44, 0.88],
            [0.02, 0.00, 0.18, 0.45, 0.64, 0.55, 0.86, 0.00, 0.16]])
    ]
    return data


if __name__ == '__main__':
    N = 9
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop(0)

    fig, axs = plt.subplots(figsize=(9, 9), nrows=2, ncols=2,
                            subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

    colors = ['b', 'r', 'g', 'm', 'y']
    
    # Plot only the first case (Basecase) on the first subplot (axs[0, 0])
    ax = axs[0, 0]  # First subplot
    ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
    ax.set_title('Basecase', weight='bold', size='medium', position=(0.5, 1.1),
                 horizontalalignment='center', verticalalignment='center')
    for d, color in zip(data[0][1], colors):
        ax.plot(theta, d, color=color)
        ax.fill(theta, d, facecolor=color, alpha=0.25, label='_nolegend_')
    ax.set_varlabels(spoke_labels)

    # add legend relative to the first plot
    labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
#     legend = ax.legend(labels, loc=(0.9, .95),labelspacing)

# %%
if __name__ == '__main__':
    N = 10
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop(0)

    fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

    colors = ['b', 'r', 'g', 'm', 'y']
    
    # Plot only the "Basecase" scenario
    ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
    ax.set_title('Basecase', weight='bold', size='medium', position=(0.5, 1.1),
                 horizontalalignment='center', verticalalignment='center')
    for d, color in zip(data[0][1], colors):
        ax.plot(theta, d, color=color)
        ax.fill(theta, d, facecolor=color, alpha=0.25, label='_nolegend_')
    ax.set_varlabels(spoke_labels)

    # Add legend
    labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
    ax.legend(labels, loc=(0.9, .95), labelspacing=0.1, fontsize='small')

    fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
             horizontalalignment='center', color='black', weight='bold',
             size='large')

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-3345947c7497> in <module>
#      16                  horizontalalignment='center', verticalalignment='center')
#      17     for d, color in zip(data[0][1], colors):
# ---> 18         ax.plot(theta, d, color=color)
#      19         ax.fill(theta, d, facecolor=color, alpha=0.25, label='_nolegend_')
#      20     ax.set_varlabels(spoke_labels)
#
# <ipython-input-83-ea389414637a> in plot(self, *args, **kwargs)
#      47
#      48         def plot(self, *args, **kwargs):
# ---> 49             lines = super().plot(*args, **kwargs)
#      50             for line in lines:
#      51                 self._close_line(line)
#
# /opt/anaconda3/envs/gideon/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
info = '''(ner, matscholar)	76.82
(ner, sofc_token)	78.78
(ner, sc_comics)	87.84
(pc, glass_non_glass)	92.58
(sf, sofc_token)	72.83
(ee, sc_comics)	91.2
(re, structured_re)	100
(re, sc_comics)	100
(sar, synthesis_actions)	94.53
(sc, sofc_sent)	76.38
(qna, squad)	66.56
(mcq, hellaswag)	80.67
(mcq, boolqa)	83.08
(mcq, story_cloze)	98.4'''.split('\n')
print([float(i.split('\t')[-1]) for i in info[:-4]])

# %%
info = '''(ner, matscholar)              76.73  0.94       81.46  0.35
(ner, sofc_token)              77.08  0.71       87.59  0.09
(ner, sc_comics)               87.12  0.60       90.90  0.19
(pc, glass_non_glass)          89.66  1.12       91.33  0.88
(sf, sofc_token)               72.44  1.32       81.26  0.94
(ee, sc_comics)                91.79  0.59       94.40  0.39
(re, structured_re)           100.00  0.00      100.00  0.00
(re, sc_comics)                99.87  0.11       99.84  0.14
(sar, synthesis_actions)       94.43  0.19       96.10  0.14
(sc, sofc_sent)                75.02  1.77       93.26  0.48
(qna, squad)                   66.33  0.30       83.23  0.37
(mcq, hellaswag)               77.36  0.57       77.42  0.57
(mcq, boolqa)                  81.89  0.34       82.53  0.31
(mcq, story_cloze)             97.80  0.20       97.80  0.20'''.split('\n')
print([float(i.split(' ')[2]) for i in info[:-4]])

# %%
# ner	[0,1,4,2]
# cls	[3,8,9]
# ee	[6,5,7]

# [sc[idx] for idx in [0,1,4,2,3,8,9,6,5,7]]
rearrancge == 
   [[83.38, 78.29, 87.22, 91.31, 74.35, 87.95, 100.0, 97.79, 94.87, 78.98], #llamat-3-chat
   [75.03, 76.01, 82.68, 89.54, 66.36, 88.36, 100.0, 91.52, 93.49, 75.84],           #llamat-3
   [76.82, 78.78, 87.84, 92.58, 72.83, 91.2, 100.0, 100.0, 94.53, 76.38],    # llamat-2-chat
   [76.73, 77.08, 87.12, 89.66, 72.44, 91.79, 100.00, 99.87, 94.43, 75.02]]

# %%
def example_data():
    data = [['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMICS-1', 'Glass','Synthesis Action','SOFC-3', 'SC-CoMICS-2','SC-CoMICS-3', 'MatSci' ],
 ('scores',
  [[83.38, 78.29, 74.35, 87.22, 91.31, 94.87, 78.98, 100.0, 87.95, 97.79],
#  [75.03, 76.01, 66.36, 82.68, 89.54, 93.49, 75.84, 100.0, 88.36, 91.52],
#  [76.82, 78.78, 72.83, 87.84, 92.58, 94.53, 76.38, 100.0, 91.2, 100.0],
#  [76.73, 77.08, 72.44, 87.12, 89.66, 94.43, 75.02, 100.0, 91.79, 99.87]
  ]),    # llamat-2
 ('With CO',
  [[0.88, 0.02, 0.02, 0.02, 0.0, 0.05, 0.0, 0.05, 0.0],
   [0.08, 0.94, 0.04, 0.02, 0.0, 0.01, 0.12, 0.04, 0.0],
   [0.01, 0.01, 0.79, 0.1, 0.0, 0.05, 0.0, 0.31, 0.0],
   [0.0, 0.02, 0.03, 0.38, 0.31, 0.31, 0.0, 0.59, 0.0],
   [0.02, 0.02, 0.11, 0.47, 0.69, 0.58, 0.88, 0.0, 0.0]]),
 ('With O3',
  [[0.89, 0.01, 0.07, 0.0, 0.0, 0.05, 0.0, 0.0, 0.03],
   [0.07, 0.95, 0.05, 0.04, 0.0, 0.02, 0.12, 0.0, 0.0],
   [0.01, 0.02, 0.86, 0.27, 0.16, 0.19, 0.0, 0.0, 0.0],
   [0.01, 0.03, 0.0, 0.32, 0.29, 0.27, 0.0, 0.0, 0.95],
   [0.02, 0.0, 0.03, 0.37, 0.56, 0.47, 0.87, 0.0, 0.0]]),
 ('CO & O3',
  [[0.87, 0.01, 0.08, 0.0, 0.0, 0.04, 0.0, 0.0, 0.01],
   [0.09, 0.95, 0.02, 0.03, 0.0, 0.01, 0.13, 0.06, 0.0],
   [0.01, 0.02, 0.71, 0.24, 0.13, 0.16, 0.0, 0.5, 0.0],
   [0.01, 0.03, 0.0, 0.28, 0.24, 0.23, 0.0, 0.44, 0.88],
   [0.02, 0.0, 0.18, 0.45, 0.64, 0.55, 0.86, 0.0, 0.16]])]
    
   
#     data2 = ['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMICS-1', 'Glass','Synthesis Action','SOFC-3', 'SC-CoMICS-2','SC-CoMICS-3', 'MatSci' ]
    
    return data

# %%
# data2 = ['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMICS-1', 'Glass','Synthesis Action','SOFC-3', 'SC-CoMICS-2','SC-CoMICS-3', 'MatSci' ]
# scrs = []

# for dat in data[1][1]:
#     temp = []
#     for idx in [0,1,4,2,3,8,9,6,5,7]:
#         temp.append(dat[idx])
#     scrs.append(temp)

# %%
data[1][1]
# Out:
# [[0.88, 0.02, 0.02, 0.02, 0.0, 0.05, 0.0, 0.05, 0.0],
#  [0.08, 0.94, 0.04, 0.02, 0.0, 0.01, 0.12, 0.04, 0.0],
#  [0.01, 0.01, 0.79, 0.1, 0.0, 0.05, 0.0, 0.31, 0.0],
#  [0.0, 0.02, 0.03, 0.38, 0.31, 0.31, 0.0, 0.59, 0.0],
#  [0.02, 0.02, 0.11, 0.47, 0.69, 0.58, 0.88, 0.0, 0.0]]

# %%
scrs
# Out:
# []

# %%
[[83.38, 78.29, 74.35, 87.22, 91.31, 94.87, 78.98, 100.0, 87.95, 97.79],
 [75.03, 76.01, 66.36, 82.68, 89.54, 93.49, 75.84, 100.0, 88.36, 91.52],
 [76.82, 78.78, 72.83, 87.84, 92.58, 94.53, 76.38, 100.0, 91.2, 100.0],
 [76.73, 77.08, 72.44, 87.12, 89.66, 94.43, 75.02, 100.0, 91.79, 99.87]]
# Out:
# [[83.38, 78.29, 74.35, 87.22, 91.31, 94.87, 78.98, 100.0, 87.95, 97.79],
#  [75.03, 76.01, 66.36, 82.68, 89.54, 93.49, 75.84, 100.0, 88.36, 91.52],
#  [76.82, 78.78, 72.83, 87.84, 92.58, 94.53, 76.38, 100.0, 91.2, 100.0],
#  [76.73, 77.08, 72.44, 87.12, 89.66, 94.43, 75.02, 100.0, 91.79, 99.87]]

# %%
if __name__ == '__main__':
    N = 10
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop(0)

    fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

#     ['#BBDEFB', '#', '#F06292', '#F8BBD0']
    colors = ['#64B5F6', '#BBDEFB', '#F06292', '#F8BBD0']
#     colors = [colors[2]]
    # Plot only the "Basecase" scenario
#     ax.set_rgrids([10, 20, 40, 60, 80, 90, 100])
#     ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
#     ax.set_title('Basecase', weight='bold', size='medium', position=(0.5, 1.1),
#                  horizontalalignment='center', verticalalignment='center')
    for d, color in zip(data[0][1], colors):
        ax.plot(theta, np.array(d)/1, color=color)
#         ax.fill(theta, np.array(d)/1, facecolor=color, alpha=0.25, label='_nolegend_')
    ax.set_varlabels(['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMIcs-1', 
          'Glass', 'Synthesis\nActions', 'SOFC-3',
          'SC-CoMIcs-2', 'SC-CoMIcs-3', 'MatSci'])
    for spine in ax.spines.values():
        spine.set_edgecolor('white')
    
    plt.grid(color='lightgrey')

    ax.set_yticklabels([])

    # Add legend
#     labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
#     ax.legend(labels, loc=(0.9, .95), labelspacing=0.1, fontsize='small')

# #     fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
#              horizontalalignment='center', color='black', weight='bold',
#              size='large')
#     
    ax.tick_params(pad=90)
#     plt.savefig('fig2_c_spider_radar_labels_micro.png', dpi=1200, bbox_inches='tight')
    plt.show()

# %%
if __name__ == '__main__':
    N = 10
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop(0)

    fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

#     ['#BBDEFB', '#', '#F06292', '#F8BBD0']
    colors = ['#64B5F6', '#BBDEFB', '#F06292', '#F8BBD0']
    
    # Plot only the "Basecase" scenario
#     ax.set_rgrids([10, 20, 40, 60, 80, 90, 100])
#     ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
#     ax.set_title('Basecase', weight='bold', size='medium', position=(0.5, 1.1),
#                  horizontalalignment='center', verticalalignment='center')
    for d, color in zip(data[0][1], colors):
        ax.plot(theta, np.array(d)/1, color=color)
#         ax.fill(theta, np.array(d)/1, facecolor=color, alpha=0.25, label='_nolegend_')
    ax.set_varlabels(['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMIcs-1', 
          'Glass', 'Synthesis\nActions', 'SOFC-3',
          'SC-CoMIcs-2', 'SC-CoMIcs-3', 'MatSci'])
    for spine in ax.spines.values():
        spine.set_edgecolor('white')
    
    plt.grid(color='lightgrey')

    ax.set_yticklabels([])

    # Add legend
#     labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
#     ax.legend(labels, loc=(0.9, .95), labelspacing=0.1, fontsize='small')

# #     fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
#              horizontalalignment='center', color='black', weight='bold',
#              size='large')
#     
    ax.tick_params(pad=90)
#     plt.savefig('fig2_c_spider_radar_labels_micro.png', dpi=1200, bbox_inches='tight')
    plt.show()

# %%
if __name__ == '__main__':
    N = 10
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop(0)

    fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

#     ['#BBDEFB', '#', '#F06292', '#F8BBD0']
    colors = ['#64B5F6', '#BBDEFB', '#F06292', '#F8BBD0']
#     colors = [colors[1]]
    # Plot only the "Basecase" scenario
#     ax.set_rgrids([10, 20, 40, 60, 80, 90, 100])
#     ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
#     ax.set_title('Basecase', weight='bold', size='medium', position=(0.5, 1.1),
#                  horizontalalignment='center', verticalalignment='center')
    for d, color in zip(data[0][1], colors):
        ax.plot(theta, np.array(d)/1, color=color)
#         ax.fill(theta, np.array(d)/1, facecolor=color, alpha=0.25, label='_nolegend_')
    ax.set_varlabels(['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMIcs-1', 
          'Glass', 'Synthesis\nActions', 'SOFC-3',
          'SC-CoMIcs-2', 'SC-CoMIcs-3', 'MatSci'])
    for spine in ax.spines.values():
        spine.set_edgecolor('white')
    
    plt.grid(color='lightgrey')

    ax.set_yticklabels([])
    ax.set_xticklabels([])

    # Add legend
#     labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
#     ax.legend(labels, loc=(0.9, .95), labelspacing=0.1, fontsize='small')

# #     fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
#              horizontalalignment='center', color='black', weight='bold',
#              size='large')
#     
    ax.tick_params(pad=90)
#     plt.savefig('fig2_c_spider_radar_only_micro_best_model.png', dpi=1200, bbox_inches='tight')
    plt.show()

# %%
seqo = '''(ner, matscholar)
(ner, sofc_token)
(ner, sc_comics)
(pc, glass_non_glass)
(sf, sofc_token)
(ee, sc_comics)
(re, structured_re)
(re, sc_comics)
(sar, synthesis_actions)
(sc, sofc_sent)'''.split('\n')

scro = '''0.21
5.72
21.81
55.33
2.45
81.64
93.68
56.22
20.44
22.45'''.split('\n')

scrdict = dict()

seqom = ['Matscholar', 'SOFC-1', 'SC-CoMICS-1', 'Glass', 'SOFC-2', 'SC-CoMICS-2', 'MatSci', 'SC-CoMICS-3', 'Synthesis Action','SOFC-3']

seqw = ['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMICS-1', 'Glass','Synthesis Action','SOFC-3', 'SC-CoMICS-2','SC-CoMICS-3', 'MatSci' ]

for lab, num in zip(seqom, scro):
    scrdict[lab] = float(num)
    
seqwanted_num = [scrdict[s] for s in seqw]

# %%
seqwanted_num
# Out:
# [0.21, 5.72, 2.45, 21.81, 55.33, 20.44, 22.45, 81.64, 56.22, 93.68]

# %%
gemini_list = [17.34, 50.4, 3.39, 48.37, 77.67, 57.57, 53.67, 84.56, 20.81, 98.66]
claude_list = [0.21, 5.72, 2.45, 21.81, 55.33, 20.44, 22.45, 81.64, 56.22, 93.68]

# %%
def example_data():
    data = [['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMICS-1', 'Glass','Synthesis Action','SOFC-3', 'SC-CoMICS-2','SC-CoMICS-3', 'MatSci' ],
 ('scores',
  [[83.38, 78.29, 74.35, 87.22, 91.31, 94.87, 78.98, 100.0, 87.95, 97.79],
 [75.03, 76.01, 66.36, 82.68, 89.54, 93.49, 75.84, 100.0, 88.36, 91.52],
 [76.82, 78.78, 72.83, 87.84, 92.58, 94.53, 76.38, 100.0, 91.2, 100.0],
 [76.73, 77.08, 72.44, 87.12, 89.66, 94.43, 75.02, 100.0, 91.79, 99.87],
 claude_list, gemini_list
  ]),    # llamat-2
 ('With CO',
  [[0.88, 0.02, 0.02, 0.02, 0.0, 0.05, 0.0, 0.05, 0.0],
   [0.08, 0.94, 0.04, 0.02, 0.0, 0.01, 0.12, 0.04, 0.0],
   [0.01, 0.01, 0.79, 0.1, 0.0, 0.05, 0.0, 0.31, 0.0],
   [0.0, 0.02, 0.03, 0.38, 0.31, 0.31, 0.0, 0.59, 0.0],
   [0.02, 0.02, 0.11, 0.47, 0.69, 0.58, 0.88, 0.0, 0.0]]),
 ('With O3',
  [[0.89, 0.01, 0.07, 0.0, 0.0, 0.05, 0.0, 0.0, 0.03],
   [0.07, 0.95, 0.05, 0.04, 0.0, 0.02, 0.12, 0.0, 0.0],
   [0.01, 0.02, 0.86, 0.27, 0.16, 0.19, 0.0, 0.0, 0.0],
   [0.01, 0.03, 0.0, 0.32, 0.29, 0.27, 0.0, 0.0, 0.95],
   [0.02, 0.0, 0.03, 0.37, 0.56, 0.47, 0.87, 0.0, 0.0]]),
 ('CO & O3',
  [[0.87, 0.01, 0.08, 0.0, 0.0, 0.04, 0.0, 0.0, 0.01],
   [0.09, 0.95, 0.02, 0.03, 0.0, 0.01, 0.13, 0.06, 0.0],
   [0.01, 0.02, 0.71, 0.24, 0.13, 0.16, 0.0, 0.5, 0.0],
   [0.01, 0.03, 0.0, 0.28, 0.24, 0.23, 0.0, 0.44, 0.88],
   [0.02, 0.0, 0.18, 0.45, 0.64, 0.55, 0.86, 0.0, 0.16]])]
    
   
#     data2 = ['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMICS-1', 'Glass','Synthesis Action','SOFC-3', 'SC-CoMICS-2','SC-CoMICS-3', 'MatSci' ]
    
    return data

# %%
if __name__ == '__main__':
    N = 10
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop(0)

    fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

#     ['#BBDEFB', '#', '#F06292', '#F8BBD0']
    colors = ['#64B5F6', '#BBDEFB', '#F06292', '#F8BBD0']
    
    colors = ['#64B5F6', '#64B5F6', '#F06292', '#F06292','#FFD54F', '#81C784']
#     colors = ['#64B5F6', '#64B5F6', '#F06292', '#F06292','#FFD54F', '#81C784']
    lss = ['-', '--', '-', '--','-','-']
    ii = 0
    for d, color in zip(data[0][1], colors):
        ax.plot(theta, np.array(d)/1, color=color, ls=lss[ii])
        ii += 1
#         ax.fill(theta, np.array(d)/1, facecolor=color, alpha=0.25, label='_nolegend_')
    ax.set_varlabels(['Matscholar', 'SOFC-1', 'SOFC-2', 'SC-CoMIcs-1', 
          'Glass', 'Synthesis\nActions', 'SOFC-3',
          'SC-CoMIcs-2', 'SC-CoMIcs-3', 'MatSci'])
    for spine in ax.spines.values():
        spine.set_edgecolor('lightgrey')
    
    plt.grid(color='lightgrey')
#     ax.set_ylim(65,100)
    
#     ax.set_rgrids([65, 75, 85, 95, 100])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    

    # Add legend
#     labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
#     ax.legend(labels, loc=(0.9, .95), labelspacing=0.1, fontsize='small')

# #     fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
#              horizontalalignment='center', color='black', weight='bold',
#              size='large')
#     
    ax.tick_params(pad=90)
    plt.savefig('fig2_c_spider_radar_only_micro_best_model_staggered.png', dpi=1200, bbox_inches='tight')
    plt.show()

# %%
# label="LLaMat-chat", color='#64B5F6') 
# label="LLaMat", color=blues[-1]) #1E88E5
# label="LLaMA-chat-FT", color='#F06292')
# label="LLaMA-FT", color=pinks[-1])

lbls = ["LLaMat-chat","LLaMat","LLaMA-chat-FT","LLaMA-FT", 'Claude-3 Haiku','Gemini-1.5 Flash-8B']

# %%
for i in range(len(colors)):
    plt.plot(np.arange(10)+i, c=colors[i], label = lbls[i], ls=lss[i])
plt.legend(loc=[1,0.01])
plt.savefig('fig2-legend_claude_gemini.png',dpi=1200, bbox_inches='tight')

# %%
colors = [colors[0], colors[0], colors[2],colors[2],  '#FFD54F', '#81C784']
lss = ['-','--','-','--','-','-']

# %%
import numpy as np
 
def combined_mean_std(means, stds, sample_sizes):
    """
    Calculate combined mean and standard deviation.
    
    Parameters:
    - means: List of means for each variable
    - stds: List of standard deviations for each variable
    - sample_sizes: List of sample sizes for each variable
    
    Returns:
    - combined_mean: Combined mean of all variables
    - combined_std: Combined standard deviation of all variables
    """
    # Calculate combined mean (weighted mean)
    total_samples = np.sum(sample_sizes)
    combined_mean = np.sum(np.array(means) * np.array(sample_sizes)) / total_samples
    
    # Calculate combined variance
    variance_within = np.sum(np.array(sample_sizes) * (np.array(stds) ** 2)) / total_samples
    variance_between = np.sum(np.array(sample_sizes) * (np.array(means) - combined_mean) ** 2) / total_samples
    combined_variance = variance_within + variance_between
    
    # Combined standard deviation is the square root of the variance
    combined_std = np.sqrt(combined_variance)
    
    return combined_mean, combined_std
 
# Example usage:
means = [5.0, 6.2, 4.8, 7.1, 5.5]  # Means for each variable
stds = [1.2, 0.9, 1.5, 1.1, 1.0]  # Standard deviations for each variable
sample_sizes = [50, 60, 55, 40, 45]  # Number of data points for each variable
 
combined_mean, combined_std = combined_mean_std(means, stds, sample_sizes)
 
print(f"Combined Mean: {combined_mean}")
print(f"Combined Standard Deviation: {combined_std}")
# Out:
# Combined Mean: 5.67
# Combined Standard Deviation: 1.416721567563648

# %%
info = '''83.38	0.68
78.29	0.43
87.22	0.1
91.31	1.26
74.35	2.07
87.95	0.72
100	0
97.79	0.72
94.87	0.21
78.98	0.4'''.split('\n')
means = [float(i.split('\t')[0]) for i in info]
stds = [float(i.split('\t')[1]) for i in info]
sample_sizes = [1061, 177,  936, 299, 179, 288, 1786, 373, 569, 1889]
combined_mean_std(means, stds, sample_sizes)
# Out:
# (88.4148855365886, 8.540082508567545)

# %%
np.mean(means), np.mean(stds)
# Out:
# (87.41400000000002, 0.659)

# %%
(ner, matscholar)
(ner, sofc_token)
(ner, sc_comics)
(pc, glass_non_glass)
(sf, sofc_token)
(ee, sc_comics)
(re, structured_re)
(re, sc_comics)
(sar, synthesis_actions)
(sc, sofc_sent)

# %%
Task Dataset Train Val
sc sofc_sent 1893 1889
re structured_re 1788 1786
sar synthesis_actions 565 569
re sc_comics 376 373
pc glass_non_glass 300 299
ee sc_comics 287 288
sf sofc_token 175 179
qna squad 1042 1042
mcq hellaswag 981 980
mcq boolqa 500 499

# %%
colors = ['#64B5F6', '#64B5F6', '#F06292', '#F06292']

# %%
tokenps = []
tokenpgps = []
