# %%
model_names = {'llamat-2-cif':"/home/mzaki4/scr16_mshiel10/mzaki4/mzaki4/cache/models--m3rg-iitd--llamat-2-cif/snapshots/437080ab240ce855eb94a42cef16c9ba9c03de65",
               'llamat-3-cif':"/home/mzaki4/scr16_mshiel10/mzaki4/mzaki4/cache/models--m3rg-iitd--llamat-3-cif/snapshots/847ed6cebdd4adff1fabe2ead1e04edc301ae63e"}

# %%
# CONDITIONAL GENERATION
sample = {
    'system': 'Apply your skills as a Material Science expert, particularly in managing CIF files, to provide insights into generating stable materials despite incomplete descriptive data.',
    'input': 'Below is a description of a bulk material. The chemical formula is Ce2NbCrN4. The elements are Ce, Nb, Cr, N. The formation energy per atom is -1.4042. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice.\nThe output should be of the following format ONLY:\nl1, l2, l3\na1, a2, a3\natom1\nx, y, z\natom2\nx, y, z\n ...\n\nl1, l2, l3 should be the predicted cell lengths.\na1, a2, a3 should be the predicted cell angles.\natom1, atom2, atom3, and so on, should be replaced with atom names and corresponding x, y, z with their coordinates in the lattice.\n',
    'output': '3.3 5.6 10.8\n89 90 90\nCe\n0.02 0.74 0.53\nCe\n0.52 0.58 0.81\nCe\n0.52 0.08 0.03\nCe\n0.02 0.24 0.31\nNb\n0.02 0.08 0.77\nNb\n0.52 0.24 0.57\nMo\n0.52 0.73 0.27\nMo\n0.02 0.59 0.07\nN\n0.02 0.82 0.92\nN\n0.52 0.50 0.42\nN\n0.52 1.00 0.41\nN\n0.02 0.33 0.93\nN\n0.02 0.91 0.18\nN\n0.52 0.42 0.16\nN\n0.52 0.91 0.68\nN\n0.02 0.41 0.66',
    'task': 'conditional_generation',
    'material': '9eb1204082.CIF'
}

sample = {'system': 'Utilize your skills as a Material Science expert, with a focus on CIF files, to tackle the question concerning the development of stable materials based on partial descriptions.',
 'input': 'Below is a description of a bulk material. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice.\nThe output should be of the following format ONLY:\nl1, l2, l3\na1, a2, a3\natom1\nx, y, z\natom2\nx, y, z\n ...\n\nl1, l2, l3 should be the predicted cell lengths.\na1, a2, a3 should be the predicted cell angles.\natom1, atom2, atom3, and so on, should be replaced with atom names and corresponding x, y, z with their coordinates in the lattice.\n',
 'output': '5.4 7.7 11.4\n75 90 90\nGd\n0.60 0.59 0.97\nGd\n0.97 0.59 0.47\nTm\n0.54 0.09 0.97\nTm\n0.47 0.88 0.30\nTm\n0.47 0.29 0.64\nTm\n0.02 0.09 0.47\nTm\n0.10 0.29 0.14\nLu\n0.10 0.88 0.80\nW\n0.03 0.81 0.10\nW\n0.54 0.81 0.61\nW\n0.03 0.36 0.84\nW\n0.54 0.36 0.34\nO\n0.82 0.24 0.29\nO\n0.32 0.14 0.32\nO\n0.30 0.80 0.99\nO\n0.74 0.24 0.79\nO\n0.63 0.58 0.61\nO\n0.24 0.14 0.82\nO\n0.83 0.88 0.94\nO\n0.74 0.88 0.45\nO\n0.43 0.72 0.77\nO\n0.32 0.03 0.62\nO\n0.74 0.93 0.15\nO\n0.74 0.29 0.49\nO\n0.13 0.45 0.67\nO\n0.93 0.58 0.11\nO\n0.64 0.60 0.33\nO\n0.24 0.03 0.12\nO\n0.82 0.93 0.65\nO\n0.26 0.37 0.45\nO\n0.82 0.29 0.99\nO\n0.13 0.72 0.27\nO\n0.30 0.37 0.95\nO\n0.43 0.45 0.17\nO\n0.26 0.80 0.49\nO\n0.93 0.60 0.83',
 'task': 'conditional_generation',
 'material': 'ff736b161d.CIF'}


# INFILL TASK


sample = {'system': 'Utilize your proficiency in crystallographic file analysis, coupled with your background in Material Science, to respond to questions regarding the prediction of the masked element in a CIF file.',
 'input': 'Below is a partial description of a bulk material where one element has been replaced with the string "[MASK]":\n5.4 7.7 11.4\n75 90 90\nGd\n0.60 0.59 0.97\nGd\n0.97 0.59 0.47\nTm\n0.54 0.09 0.97\nTm\n0.47 0.88 0.30\nTm\n0.47 0.29 0.64\nTm\n0.02 0.09 0.47\nTm\n0.10 0.29 0.14\nLu\n0.10 0.88 0.80\nW\n0.03 0.81 0.10\nW\n0.54 0.81 0.61\nW\n0.03 0.36 0.84\nW\n0.54 0.36 0.34\n[MASK]\n0.82 0.24 0.29\n[MASK]\n0.32 0.14 0.32\n[MASK]\n0.30 0.80 0.99\n[MASK]\n0.74 0.24 0.79\n[MASK]\n0.63 0.58 0.61\n[MASK]\n0.24 0.14 0.82\n[MASK]\n0.83 0.88 0.94\n[MASK]\n0.74 0.88 0.45\n[MASK]\n0.43 0.72 0.77\n[MASK]\n0.32 0.03 0.62\n[MASK]\n0.74 0.93 0.15\n[MASK]\n0.74 0.29 0.49\n[MASK]\n0.13 0.45 0.67\n[MASK]\n0.93 0.58 0.11\n[MASK]\n0.64 0.60 0.33\n[MASK]\n0.24 0.03 0.12\n[MASK]\n0.82 0.93 0.65\n[MASK]\n0.26 0.37 0.45\n[MASK]\n0.82 0.29 0.99\n[MASK]\n0.13 0.72 0.27\n[MASK]\n0.30 0.37 0.95\n[MASK]\n0.43 0.45 0.17\n[MASK]\n0.26 0.80 0.49\n[MASK]\n0.93 0.60 0.83\nGenerate an element that could replace [MASK] in the bulk material:\n',
 'output': 'O',
 'task': 'infill',
 'material': 'ff736b161d.CIF'}



# FORMULA COMPUTE

sample = {'system': 'You are a Material Science expert who works with crystallographic files (CIF files). Use your expertise to find the chemical formula of the crystal whose unit cell is described below.',
 'input': 'Below is a description dimensions, as well as of the element type and coordinates for each atom within the lattice of a stable crystal:\n5.4 7.7 11.4\n75 90 90\nGd\n0.72 0.55 0.58\nGd\n0.09 0.55 0.08\nTm\n0.67 0.05 0.58\nTm\n0.59 0.85 0.91\nTm\n0.59 0.25 0.25\nTm\n0.15 0.05 0.08\nTm\n0.22 0.25 0.75\nLu\n0.22 0.85 0.41\nW\n0.15 0.78 0.71\nW\n0.66 0.78 0.21\nW\n0.15 0.32 0.44\nW\n0.66 0.32 0.94\nO\n0.95 0.20 0.90\nO\n0.45 0.11 0.93\nO\n0.43 0.77 0.60\nO\n0.87 0.20 0.40\nO\n0.76 0.54 0.22\nO\n0.36 0.11 0.43\nO\n0.95 0.85 0.55\nO\n0.87 0.85 0.05\nO\n0.55 0.69 0.38\nO\n0.45 0.99 0.23\nO\n0.87 0.90 0.76\nO\n0.87 0.25 0.10\nO\n0.26 0.41 0.28\nO\n0.06 0.54 0.72\nO\n0.76 0.56 0.94\nO\n0.37 0.99 0.72\nO\n0.95 0.89 0.26\nO\n0.39 0.33 0.06\nO\n0.95 0.25 0.60\nO\n0.26 0.69 0.88\nO\n0.43 0.33 0.56\nO\n0.56 0.41 0.78\nO\n0.39 0.77 0.10\nO\n0.06 0.56 0.44\nFind the chemical formula of the stable crystal which has the above unit cell.\n',
 'output': 'Gd2Tm5Lu(WO6)4',
 'task': 'formula_compute',
 'material': 'ff736b161d.CIF'}


# ELEMENT GENERATION

sample = {'system': 'Employ your expertise in Material Science, particularly in the realm of CIF files, to address inquiries related to the creation of stable materials despite incomplete data.',
 'input': 'Consider the following elements:\nGd\nTm\nLu\nW\nO\nYou need to create a stable crystal that contains at least one instance of each of these elements. It should not contain elements other than the specified ones. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice:\nThe output should be of the following format ONLY:\nl1, l2, l3\na1, a2, a3\natom1\nx, y, z\natom2\nx, y, z\n ...\n\nl1, l2, l3 should be the predicted cell lengths.\na1, a2, a3 should be the predicted cell angles.\natom1, atom2, atom3, and so on, should be replaced with atom names and corresponding x, y, z with their coordinates in the lattice.\n',
 'output': '5.4 7.7 11.4\n75 90 90\nGd\n0.60 0.59 0.97\nGd\n0.97 0.59 0.47\nTm\n0.54 0.09 0.97\nTm\n0.47 0.88 0.30\nTm\n0.47 0.29 0.64\nTm\n0.02 0.09 0.47\nTm\n0.10 0.29 0.14\nLu\n0.10 0.88 0.80\nW\n0.03 0.81 0.10\nW\n0.54 0.81 0.61\nW\n0.03 0.36 0.84\nW\n0.54 0.36 0.34\nO\n0.82 0.24 0.29\nO\n0.32 0.14 0.32\nO\n0.30 0.80 0.99\nO\n0.74 0.24 0.79\nO\n0.63 0.58 0.61\nO\n0.24 0.14 0.82\nO\n0.83 0.88 0.94\nO\n0.74 0.88 0.45\nO\n0.43 0.72 0.77\nO\n0.32 0.03 0.62\nO\n0.74 0.93 0.15\nO\n0.74 0.29 0.49\nO\n0.13 0.45 0.67\nO\n0.93 0.58 0.11\nO\n0.64 0.60 0.33\nO\n0.24 0.03 0.12\nO\n0.82 0.93 0.65\nO\n0.26 0.37 0.45\nO\n0.82 0.29 0.99\nO\n0.13 0.72 0.27\nO\n0.30 0.37 0.95\nO\n0.43 0.45 0.17\nO\n0.26 0.80 0.49\nO\n0.93 0.60 0.83',
 'task': 'element_generation',
 'material': 'ff736b161d.CIF'}

# %%
import requests

# vLLM server URL
url = "http://localhost:8000/v1/completions"

samples =  {'conditional_generation': { 'system': 'Apply your skills as a Material Science expert, particularly in managing CIF files, to provide insights into generating stable materials despite incomplete descriptive data.',
                                        'input': 'Below is a description of a bulk material. The chemical formula is Ce2NbCrN4. The elements are Ce, Nb, Cr, N. The formation energy per atom is -1.4042. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice.\nThe output should be of the following format ONLY:\nl1, l2, l3\na1, a2, a3\natom1\nx, y, z\natom2\nx, y, z\n ...\n\nl1, l2, l3 should be the predicted cell lengths.\na1, a2, a3 should be the predicted cell angles.\natom1, atom2, atom3, and so on, should be replaced with atom names and corresponding x, y, z with their coordinates in the lattice.\n',
                                        'output': '3.3 5.6 10.8\n89 90 90\nCe\n0.02 0.74 0.53\nCe\n0.52 0.58 0.81\nCe\n0.52 0.08 0.03\nCe\n0.02 0.24 0.31\nNb\n0.02 0.08 0.77\nNb\n0.52 0.24 0.57\nMo\n0.52 0.73 0.27\nMo\n0.02 0.59 0.07\nN\n0.02 0.82 0.92\nN\n0.52 0.50 0.42\nN\n0.52 1.00 0.41\nN\n0.02 0.33 0.93\nN\n0.02 0.91 0.18\nN\n0.52 0.42 0.16\nN\n0.52 0.91 0.68\nN\n0.02 0.41 0.66',
                                        'task': 'conditional_generation',
                                        'material': '9eb1204082.CIF'
                                    },
            'infill': {'system': 'Utilize your proficiency in crystallographic file analysis, coupled with your background in Material Science, to respond to questions regarding the prediction of the masked element in a CIF file.',
                        'input': 'Below is a partial description of a bulk material where one element has been replaced with the string "[MASK]":\n5.4 7.7 11.4\n75 90 90\nGd\n0.60 0.59 0.97\nGd\n0.97 0.59 0.47\nTm\n0.54 0.09 0.97\nTm\n0.47 0.88 0.30\nTm\n0.47 0.29 0.64\nTm\n0.02 0.09 0.47\nTm\n0.10 0.29 0.14\nLu\n0.10 0.88 0.80\nW\n0.03 0.81 0.10\nW\n0.54 0.81 0.61\nW\n0.03 0.36 0.84\nW\n0.54 0.36 0.34\n[MASK]\n0.82 0.24 0.29\n[MASK]\n0.32 0.14 0.32\n[MASK]\n0.30 0.80 0.99\n[MASK]\n0.74 0.24 0.79\n[MASK]\n0.63 0.58 0.61\n[MASK]\n0.24 0.14 0.82\n[MASK]\n0.83 0.88 0.94\n[MASK]\n0.74 0.88 0.45\n[MASK]\n0.43 0.72 0.77\n[MASK]\n0.32 0.03 0.62\n[MASK]\n0.74 0.93 0.15\n[MASK]\n0.74 0.29 0.49\n[MASK]\n0.13 0.45 0.67\n[MASK]\n0.93 0.58 0.11\n[MASK]\n0.64 0.60 0.33\n[MASK]\n0.24 0.03 0.12\n[MASK]\n0.82 0.93 0.65\n[MASK]\n0.26 0.37 0.45\n[MASK]\n0.82 0.29 0.99\n[MASK]\n0.13 0.72 0.27\n[MASK]\n0.30 0.37 0.95\n[MASK]\n0.43 0.45 0.17\n[MASK]\n0.26 0.80 0.49\n[MASK]\n0.93 0.60 0.83\nGenerate an element that could replace [MASK] in the bulk material:\n',
                        'output': 'O',
                        'task': 'infill',
                        'material': 'ff736b161d.CIF'},

            'formula_compute':{'system': 'You are a Material Science expert who works with crystallographic files (CIF files). Use your expertise to find the chemical formula of the crystal whose unit cell is described below.',
                                'input': 'Below is a description dimensions, as well as of the element type and coordinates for each atom within the lattice of a stable crystal:\n5.4 7.7 11.4\n75 90 90\nGd\n0.72 0.55 0.58\nGd\n0.09 0.55 0.08\nTm\n0.67 0.05 0.58\nTm\n0.59 0.85 0.91\nTm\n0.59 0.25 0.25\nTm\n0.15 0.05 0.08\nTm\n0.22 0.25 0.75\nLu\n0.22 0.85 0.41\nW\n0.15 0.78 0.71\nW\n0.66 0.78 0.21\nW\n0.15 0.32 0.44\nW\n0.66 0.32 0.94\nO\n0.95 0.20 0.90\nO\n0.45 0.11 0.93\nO\n0.43 0.77 0.60\nO\n0.87 0.20 0.40\nO\n0.76 0.54 0.22\nO\n0.36 0.11 0.43\nO\n0.95 0.85 0.55\nO\n0.87 0.85 0.05\nO\n0.55 0.69 0.38\nO\n0.45 0.99 0.23\nO\n0.87 0.90 0.76\nO\n0.87 0.25 0.10\nO\n0.26 0.41 0.28\nO\n0.06 0.54 0.72\nO\n0.76 0.56 0.94\nO\n0.37 0.99 0.72\nO\n0.95 0.89 0.26\nO\n0.39 0.33 0.06\nO\n0.95 0.25 0.60\nO\n0.26 0.69 0.88\nO\n0.43 0.33 0.56\nO\n0.56 0.41 0.78\nO\n0.39 0.77 0.10\nO\n0.06 0.56 0.44\nFind the chemical formula of the stable crystal which has the above unit cell.\n',
                                'output': 'Gd2Tm5Lu(WO6)4',
                                'task': 'formula_compute',
                                'material': 'ff736b161d.CIF'},
            'element_generation':{'system': 'Employ your expertise in Material Science, particularly in the realm of CIF files, to address inquiries related to the creation of stable materials despite incomplete data.',
                                'input': 'Consider the following elements:\nGd\nTm\nLu\nW\nO\nYou need to create a stable crystal that contains at least one instance of each of these elements. It should not contain elements other than the specified ones. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice:\nThe output should be of the following format ONLY:\nl1, l2, l3\na1, a2, a3\natom1\nx, y, z\natom2\nx, y, z\n ...\n\nl1, l2, l3 should be the predicted cell lengths.\na1, a2, a3 should be the predicted cell angles.\natom1, atom2, atom3, and so on, should be replaced with atom names and corresponding x, y, z with their coordinates in the lattice.\n',
                                'output': '5.4 7.7 11.4\n75 90 90\nGd\n0.60 0.59 0.97\nGd\n0.97 0.59 0.47\nTm\n0.54 0.09 0.97\nTm\n0.47 0.88 0.30\nTm\n0.47 0.29 0.64\nTm\n0.02 0.09 0.47\nTm\n0.10 0.29 0.14\nLu\n0.10 0.88 0.80\nW\n0.03 0.81 0.10\nW\n0.54 0.81 0.61\nW\n0.03 0.36 0.84\nW\n0.54 0.36 0.34\nO\n0.82 0.24 0.29\nO\n0.32 0.14 0.32\nO\n0.30 0.80 0.99\nO\n0.74 0.24 0.79\nO\n0.63 0.58 0.61\nO\n0.24 0.14 0.82\nO\n0.83 0.88 0.94\nO\n0.74 0.88 0.45\nO\n0.43 0.72 0.77\nO\n0.32 0.03 0.62\nO\n0.74 0.93 0.15\nO\n0.74 0.29 0.49\nO\n0.13 0.45 0.67\nO\n0.93 0.58 0.11\nO\n0.64 0.60 0.33\nO\n0.24 0.03 0.12\nO\n0.82 0.93 0.65\nO\n0.26 0.37 0.45\nO\n0.82 0.29 0.99\nO\n0.13 0.72 0.27\nO\n0.30 0.37 0.95\nO\n0.43 0.45 0.17\nO\n0.26 0.80 0.49\nO\n0.93 0.60 0.83',
                                'task': 'element_generation',
                                'material': 'ff736b161d.CIF'}
           }

tasks = ['conditional_generation', 'infill', 'formula_compute', 'element_generation']

task = tasks[0]
sample = samples[task]
# Build prompt same as in your HF code
eval_prompt = f"{sample['system']} " + f"input-{sample['input']}" + "output-"

# Prepare payload for vLLM
payload = {
    "model": model_names['llamat-2-cif'],
    "prompt": eval_prompt,
    "max_tokens": 1024,
    "temperature": 0.0,
    "top_p": 0.95
}

# Send request
response = requests.post(url, json=payload)

# Parse output
result = response.json()

print('INPUT')
print(eval_prompt)
print(10*'=')
print(result["choices"][0]["text"])
# Out:
# INPUT
# Apply your skills as a Material Science expert, particularly in managing CIF files, to provide insights into generating stable materials despite incomplete descriptive data. input-Below is a description of a bulk material. The chemical formula is Ce2NbCrN4. The elements are Ce, Nb, Cr, N. The formation energy per atom is -1.4042. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice.
# The output should be of the following format ONLY:
# l1, l2, l3
# a1, a2, a3
# atom1
# x, y, z
# atom2
# x, y, z
#  ...
#
# l1, l2, l3 should be the predicted cell lengths.
# a1, a2, a3 should be the predicted cell angles.
# atom1, atom2, atom3, and so on, should be replaced with atom names and corresponding x, y, z with their coordinates in the lattice.
# output-
# ==========
#  3.3 5.7 10.9
# 90 90 90
# Ce
# 0.10 0.11 0.11
# Ce
# 0.10 0.61 0.90
# Ce
# 0.60 0.96 0.40
# Ce
# 0.60 0.46 0.61
# Nb
# 0.10 0.46 0.36
# Nb
# 0.10 0.96 0.65
# Cr
# 0.60 0.61 0.15
# Cr
# 0.60 0.11 0.86
# N
# 0.10 0.20 0.50
# N
# 0.10 0.70 0.51
# N
# 0.60 0.87 0.01
# N
# 0.60 0.37 0.00
# N
# 0.10 0.79 0.25
# N
# 0.10 0.29 0.76
# N
# 0.60 0.28 0.26
# N
# 0.60 0.78 0.75

# %%
import requests

# %%
# UNCONDITIONAL GENERATION

url = "http://localhost:8000/v1/completions"

sample = {'system': 'You are a Material Science expert who works with crystallographic files (CIF files). Use your expertise to find the chemical formula of the crystal whose unit cell is described below.',,
 'input': 'What is XRD?',
 'output': '5.4 7.7 11.4\n75 90 90\nGd\n0.60 0.59 0.97\nGd\n0.97 0.59 0.47\nTm\n0.54 0.09 0.97\nTm\n0.47 0.88 0.30\nTm\n0.47 0.29 0.64\nTm\n0.02 0.09 0.47\nTm\n0.10 0.29 0.14\nLu\n0.10 0.88 0.80\nW\n0.03 0.81 0.10\nW\n0.54 0.81 0.61\nW\n0.03 0.36 0.84\nW\n0.54 0.36 0.34\nO\n0.82 0.24 0.29\nO\n0.32 0.14 0.32\nO\n0.30 0.80 0.99\nO\n0.74 0.24 0.79\nO\n0.63 0.58 0.61\nO\n0.24 0.14 0.82\nO\n0.83 0.88 0.94\nO\n0.74 0.88 0.45\nO\n0.43 0.72 0.77\nO\n0.32 0.03 0.62\nO\n0.74 0.93 0.15\nO\n0.74 0.29 0.49\nO\n0.13 0.45 0.67\nO\n0.93 0.58 0.11\nO\n0.64 0.60 0.33\nO\n0.24 0.03 0.12\nO\n0.82 0.93 0.65\nO\n0.26 0.37 0.45\nO\n0.82 0.29 0.99\nO\n0.13 0.72 0.27\nO\n0.30 0.37 0.95\nO\n0.43 0.45 0.17\nO\n0.26 0.80 0.49\nO\n0.93 0.60 0.83',
 'task': 'element_generation',
 'material': 'ff736b161d.CIF'}

# Build prompt same as in your HF code
eval_prompt = f"{sample['system']} " + f"input-{sample['input']}" + "output-"


# Send request
response = requests.post(url, json=payload)

# Parse output
result = response.json()
print(result["choices"][0]["text"])
# Out:
#  XRD stands for X-ray diffraction. It is a technique used to determine the crystal structure and phase composition of a material by measuring the diffraction of X-rays from the material, providing information on lattice constants, strain, and crystallite size.
#
#
# What is XRD analysis?
#
#
# XRD analysis stands for X-ray diffraction.
#
#
# XRD analysis is a technique used to determine the crystal structure and phase composition of a material by measuring the diffraction of X-rays from the material, providing information on lattice constants, strain, and crystallite size.
#
#
# XRD analysis
#
#
# provides detailed insights into the material's structure, offering valuable data for material selection, performance prediction, and quality control in various industrial and research applications.
#
#
#
#
#
# XRD analysis
#
#
# has a wide range of applications across materials science, materials engineering, and material processing.
#
#
# Used to characterize the crystallinity and phase composition of materials, the data from XRD analysis can be used to optimize material properties and enhance their performance for specific applications
#
#
# by understanding the material's structural characteristics
#
#
# at the microscopic level
#
#
# ,
#
#
# XRD analysis is a versatile tool for advanced material characterization
#
#
# and material selection
#
#
# in a variety of high-tech and industrial fields.
#
#
#
#
#
# XRD analysis
#
#
# offers a non-destructive method to explore the material's intrinsic properties, making it essential for material scientists and engineers
#
#
# working on material development, quality assurance, and performance optimization
#
#
# in various industrial and research applications
#
#
# .
#
#
# XRD analysis is a technique used to determine the crystal structure and phase composition of a material by measuring the diffraction of X-rays from the material, providing information on lattice constants, strain, and crystallite size.
#
#
# XRD analysis
#
#
# stands for X-ray diffraction.
#
#
# XRD analysis is a versatile tool for advanced material characterization and material selection in a variety of high-tech and industrial fields.
#
#
# XRD analysis
#
#
# provides a non-destructive method to explore the material's intrinsic properties
#
#
# , making it essential for material scientists and engineers
#
#
# working on material development, quality assurance, and performance optimization
#
#
# in various industrial and research applications
#
#
# .
#
#
# XRD analysis
#
#
# is a technique used to determine the crystal structure and phase composition of a material by measuring the diffraction of X-rays from the material, providing information on lattice constants, strain, and crystallite size
#
#
# .
#
#
# XRD analysis
#
#
# stands for X-ray diffraction
#
#
# .
#
#
# XRD analysis
#
#
# provides a non-destructive method to explore the material's intrinsic properties, making it essential for material scientists and engineers
#
#
# working on material development, quality assurance, and performance optimization
#
#
# in various industrial and research applications
#
#
# .
#
#
# XRD analysis
#
#
# is a versatile tool for advanced material characterization and material selection
#
#
# in a variety of high-tech and industrial fields.
#
#
# XRD analysis
#
#
# stands for X-ray diffraction.
#
#
# XRD analysis
#
#
# provides a non-destructive method to explore the material's intrinsic properties, making it essential for material scientists and engineers
#
#
# working on material development, quality assurance, and performance optimization
#
#
# in various industrial and research applications
#
#
# .
#
#
# XRD analysis
#
#
# is a technique used to determine the crystal structure and phase composition of a material by measuring the diffraction of X-rays from the material, providing information on lattice constants, strain, and crystallite size
#
#
# .
#
#
# XRD analysis
#
#
# stands for X-ray diffraction

# %%
prompt = "Below is a description of a bulk material. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice:\n"

# %%
sample = {
    'system': '',
    'input': "Below is a description of a bulk material. Generate a description of the lengths and angles of the lattice vectors and then the element type and coordinates for each atom within the lattice. \n output -",
    'output': '3.3 5.6 10.8\n89 90 90\nCe\n0.02 0.74 0.53\nCe\n0.52 0.58 0.81\nCe\n0.52 0.08 0.03\nCe\n0.02 0.24 0.31\nNb\n0.02 0.08 0.77\nNb\n0.52 0.24 0.57\nMo\n0.52 0.73 0.27\nMo\n0.02 0.59 0.07\nN\n0.02 0.82 0.92\nN\n0.52 0.50 0.42\nN\n0.52 1.00 0.41\nN\n0.02 0.33 0.93\nN\n0.02 0.91 0.18\nN\n0.52 0.42 0.16\nN\n0.52 0.91 0.68\nN\n0.02 0.41 0.66',
    'task': 'conditional_generation',
    'material': '9eb1204082.CIF'
}

# Build prompt same as in your HF code
eval_prompt = f"{sample['system']} " + f"input-{sample['input']}" + "output-"

# Prepare payload for vLLM
payload = {
    "model": model_names["llamat-2-cif"],
    "prompt": eval_prompt,
    "max_tokens": 1024,
    "temperature": 1,
    "top_p": 0.95
}

# Send request
response = requests.post(url, json=payload)

# Parse output
result = response.json()
print(result["choices"][0]["text"])
# Out:
#  5.7 5.7 10.5
# 86 86 120
# Li
# 0.43 0.49 0.52
# Li
# 0.14 0.83 0.52
# Li
# 0.40 0.19 0.29
# Li
# 0.39 0.83 0.02
# Li
# 0.79 0.14 0.52
# Li
# 0.77 0.47 0.79
# Li
# 0.75 0.81 0.29
# Li
# 0.08 0.14 0.02
# Li
# 0.41 0.15 0.79
# Li
# 0.76 0.49 0.29
# Nb
# 0.41 0.49 0.02
# Nb
# 0.06 0.83 0.79
# Nb
# 0.09 0.16 0.29
# Nb
# 0.76 0.46 0.52
# Nb
# 0.08 0.50 0.02
# Nb
# 0.74 0.81 0.79
# N
# 0.42 0.84 0.65
# N
# 0.42 0.17 0.15
# N
# 0.74 0.80 0.46
# N
# 0.74 0.15 0.96
# N
# 0.07 0.49 0.65
# N
# 0.08 0.16 0.66
# N
# 0.42 0.48 0.84
# N
# 0.76 0.81 0.96
# N
# 0.09 0.47 0.15
# N
# 0.06 0.82 0.16
# N
# 0.73 0.15 0.34
# N
# 0.41 0.47 0.34
# N
# 0.76 0.50 0.16
# N
# 0.40 0.81 0.34
# N
# 0.09 0.15 0.46
# N
# 0.06 0.83 0.96
# N
# 0.73 0.49 0.66
# N
# 0.39 0.15 0.65
# N
# 0.09 0.81 0.34
# N
# 0.74 0.48 0.96

# %%
# Prepare payload for vLLM
payload = {
    "model": ".cache/huggingface/hub/models--m3rg-iitd--llamat-2-chat/snapshots/2b67f6910c90d34e04ef5cb39ae0e5d7ae2e1259",
    "prompt": "What is XRD?",
    "max_tokens": 1024,
    "temperature": 1,
    "top_p": 0.95
}
